# %% [markdown]
# # Origence Client Model 3
#
# With LTV feature
#
# Total rows: 595176
#
# Train: 363870 rows (61.14%) start date: 2019-04-01 end date: 2022-03-13
#
# Valid: 115341 rows (19.38%) start date: 2022-03-13 end date: 2022-07-28
#
# Test:  115965 rows (19.48%) start date: 2022-07-28 end date: 2023-03-31

# %%
import os
import pandas as pd
import json

from model_engine.assets.utils import load_asset
from model_engine.io.loaders import load_json
from model_engine.power.post_sale import PowerModelBuilder
from model_engine.analysis.suggesters import evaluate_datesplits
import warnings

from zaml.common.utils import load_state

import model_engine, zaml
model_engine.__version__, zaml.__version__
# Out:
# ('v1.13.0', '34.5.2')

# %%
from model_engine.model_builder.asset_parser import asset_parser
from model_engine.model_builder import ModelBuilder

# %%
with open('project_info.json', "r") as f:
    project_info = json.load(f)
input_client_name = project_info['client_name']
model_type = project_info['national_model_category'] # options are 'standard_model', 'mega_model', 'standard_model_member_data', 'standard_model_ln_data', 'standard_model_ln_member_data'- None defaults to 'standard_model'

print(input_client_name, model_type)
# Out:
# origencepocv2 standard_model_member_data

# %% [markdown]
# ## 1. Unfold Model

# %%
input_model_id = 'clientmodel3a'
input_target_name = 'final_DQ60_m24'


final_model_output_path = f'/d/shared/silver_projects_v2/origencepocv2/autoloanv1/modeling/model_artifacts/autoloan/{input_model_id}'
aux_model_output_path = f'/d/shared/silver_projects_v2/origencepocv2/autoloanv1/modeling/auxiliary_model_artifacts/autoloan/{input_model_id}'


print(f'Final model path: {final_model_output_path}')
print(f'aux model path: {aux_model_output_path}')
# Out:
# Final model path: /d/shared/silver_projects_v2/origencepocv2/autoloanv1/modeling/model_artifacts/autoloan/clientmodel3a
# aux model path: /d/shared/silver_projects_v2/origencepocv2/autoloanv1/modeling/auxiliary_model_artifacts/autoloan/clientmodel3a

# %%
asset = json.load(open(f'./{input_model_id}_asset.json'))

# %%
model_builder = ModelBuilder(asset)
model_builder.configure_run(final_model_output_path, 
                            cache=True) 

state = asset_parser(asset)

input_asset = (json.dumps(state['input_asset'], indent=4))
print(input_asset)
# Out:
# WARNING:py.warnings:Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 11.0.0, and the legacy implementation will be removed in a future version.
#
# WARNING:py.warnings:Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 11.0.0, and the legacy implementation will be removed in a future version.
#
# WARNING:py.warnings:Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 11.0.0, and the legacy implementation will be removed in a future version.
#
# WARNING:py.warnings:Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 11.0.0, and the legacy implementation will be removed in a future version.
#
# WARNING:py.warnings:Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 11.0.0, and the legacy implementation will be removed in a future version.
#
# WARNING:py.warnings:Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 11.0.0, and the legacy implementation will be removed in a future version.
#
# WARNING:py.warnings:Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 11.0.0, and the legacy implementation will be removed in a future version.
#
# WARNING:py.warnings:Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 11.0.0, and the legacy implementation will be removed in a future version.
#
# WARNING:py.warnings:Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 11.0.0, and the legacy implementation will be removed in a future version.
#
# WARNING:py.warnings:Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 11.0.0, and the legacy implementation will be removed in a future version.
#
# WARNING:py.warnings:Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 11.0.0, and the legacy implementation will be removed in a future version.
#
# WARNING:py.warnings:Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 11.0.0, and the legacy implementation will be removed in a future version.
#
# WARNING:py.warnings:Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 11.0.0, and the legacy implementation will be removed in a future version.
#
# WARNING:py.warnings:Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 11.0.0, and the legacy implementation will be removed in a future version.
#
# WARNING:py.warnings:Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 11.0.0, and the legacy implementation will be removed in a future version.
#
# WARNING:py.warnings:Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 11.0.0, and the legacy implementation will be removed in a future version.
# {
#     "data": {
#         "trade": {
#             "asset": "equifax/cms_6/trade.json",
#             "data": "#/home/lyt/CLIENTS/client-project-penfed/modeling/client_models/sample_files/trade_sampled_files.json",
#             "io_params": {
#                 "drop_duplicates": true,
#                 "keep_features": [
#                     "trade_acctType__count",
#                     "trade_blncAmt__mean_by_acctType_auto",
#                     "trade_blncAmt__min_by_acctType_education",
#                     "trade_blncAmt_accts_never_dq__max",
#                     "trade_blncAmt_accts_never_dq__max_by_ecoa_joint",
#                     "trade_blncAmt_accts_never_dq__max_by_prtfType_mortgage",
#                     "trade_blncAmt_accts_never_dq__mean_by_acctType_unsecure",
#                     "trade_blncAmt_accts_never_dq__mean_by_ecoa_joint",
#                     "trade_blncAmt_accts_never_dq__sum",
#                     "trade_blncAmt_accts_never_dq__sum_by_prtfType_mortgage",
#                     "trade_blncAmt_accts_opened_12m__max_by_ecoa_individual",
#                     "trade_blncAmt_accts_opened_12m__mean_by_ecoa_individual",
#                     "trade_blncAmt_accts_opened_12m__sum_by_acctType_unsecure",
#                     "trade_blncAmt_accts_opened_12m__sum_by_ecoa_individual",
#                     "trade_blncAmt_accts_with_rcntPmt__max",
#                     "trade_blncAmt_accts_with_rcntPmt__mean_by_acctType_credit_card",
#                     "trade_blncAmt_accts_with_rcntPmt__mean_by_acctType_education",
#                     "trade_blncAmt_accts_with_rcntPmt__mean_by_prtfType_revolving",
#                     "trade_blncAmt_accts_with_rcntPmt__min",
#                     "trade_blncAmt_accts_with_rcntPmt__min_by_ecoa_joint",
#                     "trade_blncAmt_accts_with_rcntPmt__min_by_prtfType_revolving",
#                     "trade_blncAmt_accts_with_rcntPmt__sum_by_acctType_education",
#                     "trade_blncAmt_active_accts__sum",
#                     "trade_blncAmt_active_accts__sum_by_prtfType_revolving",
#                     "trade_blncAmt_all_derog_accts__max",
#                     "trade_blncAmt_all_derog_accts__max_by_acctType_auto",
#                     "trade_blncAmt_all_derog_accts__max_by_ecoa_individual",
#                     "trade_blncAmt_all_derog_accts__max_by_prtfType_installment",
#                     "trade_blncAmt_all_derog_accts__mean",
#                     "trade_blncAmt_all_non_derog_accts__mean_by_acctType_auto",
#                     "trade_blncAmt_all_non_derog_accts__mean_by_ecoa_individual",
#                     "trade_blncAmt_all_non_derog_accts__mean_by_prtfType_revolving",
#                     "trade_blncAmt_with_crdUtl_gt_0.25__sum_by_ecoa_individual",
#                     "trade_blncAmt_with_crdUtl_gt_0.5__mean_by_ecoa_individual",
#                     "trade_blncAmt_with_crdUtl_gt_0.5__sum_by_ecoa_individual",
#                     "trade_blncAmt_with_crdUtl_gt_1__mean_by_ecoa_individual",
#                     "trade_blncAmt_with_hc_to_cl_gt_0.25__mean",
#                     "trade_blncAmt_with_hc_to_cl_gt_0.25__mean_by_ecoa_individual",
#                     "trade_blncAmt_with_hc_to_cl_gt_0.5__mean_by_ecoa_individual",
#                     "trade_blnc_to_hc__max_by_acctType_auto",
#                     "trade_blnc_to_hc__max_by_acctType_secure",
#                     "trade_blnc_to_hc__max_by_acctType_unsecure",
#                     "trade_blnc_to_hc__mean_by_acctType_unsecure",
#                     "trade_blnc_to_hc__mean_by_prtfType_revolving",
#                     "trade_blnc_to_hc_accts_never_dq__max_by_prtfType_mortgage",
#                     "trade_blnc_to_hc_accts_never_dq__min_by_prtfType_installment",
#                     "trade_blnc_to_hc_accts_opened_12m__max_by_acctType_secure",
#                     "trade_blnc_to_hc_accts_opened_12m__mean_by_prtfType_revolving",
#                     "trade_blnc_to_hc_accts_opened_12m__sum_by_acctType_unsecure",
#                     "trade_blnc_to_hc_accts_with_rcntPmt__max_by_acctType_auto",
#                     "trade_blnc_to_hc_accts_with_rcntPmt__max_by_prtfType_revolving",
#                     "trade_blnc_to_hc_accts_with_rcntPmt__mean_by_acctType_credit_card",
#                     "trade_blnc_to_hc_accts_with_rcntPmt__mean_by_prtfType_revolving",
#                     "trade_blnc_to_hc_accts_with_rcntPmt__min_by_prtfType_installment",
#                     "trade_blnc_to_hc_accts_with_rcntPmt__min_by_prtfType_revolving",
#                     "trade_blnc_to_hc_active_accts__max_by_acctType_secure",
#                     "trade_blnc_to_hc_active_accts__mean_by_acctType_credit_card",
#                     "trade_blnc_to_hc_active_accts__mean_by_prtfType_revolving",
#                     "trade_blnc_to_hc_all_non_derog_accts__max_by_prtfType_installment",
#                     "trade_blnc_to_hc_all_non_derog_accts__mean_by_acctType_auto",
#                     "trade_blnc_to_hc_all_non_derog_accts__mean_by_prtfType_installment",
#                     "trade_blnc_to_hc_all_non_derog_accts__min_by_prtfType_installment",
#                     "trade_blnc_to_hc_with_crdUtl_gt_0.25__max_by_prtfType_revolving",
#                     "trade_blnc_to_hc_with_crdUtl_gt_0.25__min_by_prtfType_revolving",
#                     "trade_blnc_to_hc_with_crdUtl_gt_0.5__max_by_prtfType_revolving",
#                     "trade_blnc_to_hc_with_hc_to_cl_gt_0.25__mean_by_prtfType_revolving",
#                     "trade_blnc_to_hc_with_hc_to_cl_gt_0.5__mean_by_prtfType_revolving",
#                     "trade_blnc_to_hc_with_hc_to_cl_gt_1__max_by_prtfType_revolving",
#                     "trade_blnc_to_hc_with_hc_to_cl_gt_1__mean_by_prtfType_revolving",
#                     "trade_clAmt__max_by_prtfType_revolving",
#                     "trade_clAmt__mean_by_acctType_credit_card",
#                     "trade_clAmt__mean_by_prtfType_revolving",
#                     "trade_clAmt_accts_never_dq__max_by_acctType_credit_card",
#                     "trade_clAmt_accts_never_dq__max_by_prtfType_revolving",
#                     "trade_clAmt_accts_never_dq__mean_by_acctType_credit_card",
#                     "trade_clAmt_accts_never_dq__min_by_acctType_credit_card",
#                     "trade_clAmt_accts_with_rcntPmt__max_by_prtfType_revolving",
#                     "trade_clAmt_accts_with_rcntPmt__mean_by_acctType_credit_card",
#                     "trade_clAmt_accts_with_rcntPmt__mean_by_prtfType_revolving",
#                     "trade_clAmt_accts_with_rcntPmt__min_by_prtfType_revolving",
#                     "trade_clAmt_accts_with_rcntPmt__sum_by_prtfType_revolving",
#                     "trade_clAmt_active_accts__max_by_prtfType_revolving",
#                     "trade_clAmt_active_accts__mean_by_acctType_credit_card",
#                     "trade_clAmt_active_accts__mean_by_prtfType_revolving",
#                     "trade_clAmt_active_accts__min_by_acctType_credit_card",
#                     "trade_clAmt_active_accts__min_by_prtfType_revolving",
#                     "trade_clAmt_all_non_derog_accts__max_by_acctType_credit_card",
#                     "trade_clAmt_all_non_derog_accts__max_by_prtfType_revolving",
#                     "trade_clAmt_all_non_derog_accts__mean_by_acctType_credit_card",
#                     "trade_clAmt_all_non_derog_accts__mean_by_prtfType_revolving",
#                     "trade_clAmt_with_hc_to_cl_gt_0.25__mean_by_prtfType_revolving",
#                     "trade_clAmt_with_hc_to_cl_gt_0.5__mean_by_prtfType_revolving",
#                     "trade_crdUtl__max_by_acctType_credit_card",
#                     "trade_crdUtl__max_by_prtfType_revolving",
#                     "trade_crdUtl__mean_by_prtfType_revolving",
#                     "trade_crdUtl_accts_opened_12m__max_by_prtfType_revolving",
#                     "trade_crdUtl_accts_with_rcntPmt__mean_by_prtfType_revolving",
#                     "trade_crdUtl_accts_with_rcntPmt__min_by_prtfType_revolving",
#                     "trade_crdUtl_active_accts__max_by_prtfType_revolving",
#                     "trade_crdUtl_active_accts__mean_by_prtfType_revolving",
#                     "trade_hcAmt__max_by_acctType_education",
#                     "trade_hcAmt__min_by_acctType_education",
#                     "trade_hcAmt__min_by_prtfType_installment",
#                     "trade_hcAmt_accts_never_dq__max_by_prtfType_mortgage",
#                     "trade_hcAmt_accts_never_dq__mean_by_prtfType_revolving",
#                     "trade_hcAmt_accts_never_dq__min_by_ecoa_joint",
#                     "trade_hcAmt_accts_never_dq__min_by_prtfType_installment",
#                     "trade_hcAmt_accts_never_dq__min_by_prtfType_mortgage",
#                     "trade_hcAmt_accts_never_dq__sum",
#                     "trade_hcAmt_accts_never_dq__sum_by_ecoa_joint",
#                     "trade_hcAmt_accts_never_dq__sum_by_prtfType_installment",
#                     "trade_hcAmt_accts_never_dq__sum_by_prtfType_mortgage",
#                     "trade_hcAmt_accts_with_rcntPmt__max_by_acctType_education",
#                     "trade_hcAmt_accts_with_rcntPmt__max_by_ecoa_joint",
#                     "trade_hcAmt_accts_with_rcntPmt__mean",
#                     "trade_hcAmt_accts_with_rcntPmt__mean_by_acctType_education",
#                     "trade_hcAmt_accts_with_rcntPmt__min",
#                     "trade_hcAmt_accts_with_rcntPmt__sum",
#                     "trade_hcAmt_accts_with_rcntPmt__sum_by_acctType_education",
#                     "trade_hcAmt_accts_with_rcntPmt__sum_by_ecoa_joint",
#                     "trade_hcAmt_all_derog_accts__max",
#                     "trade_hcAmt_all_derog_accts__max_by_acctType_auto",
#                     "trade_hcAmt_all_derog_accts__mean",
#                     "trade_hcAmt_all_derog_accts__min",
#                     "trade_hcAmt_all_derog_accts__sum_by_acctType_auto",
#                     "trade_hcAmt_all_non_derog_accts__max_by_ecoa_joint",
#                     "trade_hcAmt_all_non_derog_accts__max_by_prtfType_revolving",
#                     "trade_hcAmt_all_non_derog_accts__mean_by_prtfType_installment",
#                     "trade_hcAmt_all_non_derog_accts__mean_by_prtfType_revolving",
#                     "trade_hcAmt_all_non_derog_accts__sum",
#                     "trade_hcAmt_all_non_derog_accts__sum_by_ecoa_joint",
#                     "trade_hcAmt_all_non_derog_accts__sum_by_prtfType_mortgage",
#                     "trade_hcAmt_with_crdUtl_gt_0.5__sum_by_ecoa_individual",
#                     "trade_hc_to_cl_accts_opened_12m__max_by_acctType_credit_card",
#                     "trade_hc_to_cl_accts_opened_12m__max_by_prtfType_revolving",
#                     "trade_hc_to_cl_accts_with_rcntPmt__max_by_prtfType_revolving",
#                     "trade_hc_to_cl_accts_with_rcntPmt__mean_by_prtfType_revolving",
#                     "trade_hc_to_cl_accts_with_rcntPmt__min_by_prtfType_revolving",
#                     "trade_hc_to_cl_active_accts__max_by_prtfType_revolving",
#                     "trade_hc_to_cl_active_accts__min_by_prtfType_revolving",
#                     "trade_hc_to_cl_all_non_derog_accts__max_by_acctType_credit_card",
#                     "trade_hc_to_cl_all_non_derog_accts__min_by_acctType_credit_card",
#                     "trade_months_since_lstPmtDate__mean_by_acctType_education",
#                     "trade_months_since_lstPmtDate__min_by_acctType_education",
#                     "trade_months_since_lstPmtDate__min_by_prtfType_mortgage",
#                     "trade_months_since_lstPmtDate__min_by_prtfType_revolving",
#                     "trade_months_since_lstPmtDate__sum_by_acctType_education",
#                     "trade_months_since_openDate__max",
#                     "trade_months_since_openDate__max_by_acctType_auto",
#                     "trade_months_since_openDate__max_by_acctType_credit_card",
#                     "trade_months_since_openDate__max_by_ecoa_individual",
#                     "trade_months_since_openDate__max_by_ecoa_joint",
#                     "trade_months_since_openDate__max_by_prtfType_revolving",
#                     "trade_months_since_openDate__mean_by_acctType_auto",
#                     "trade_months_since_openDate__mean_by_acctType_credit_card",
#                     "trade_months_since_openDate__mean_by_ecoa_individual",
#                     "trade_months_since_openDate__mean_by_prtfType_installment",
#                     "trade_months_since_openDate__mean_by_prtfType_revolving",
#                     "trade_months_since_openDate__min_by_ecoa_individual",
#                     "trade_months_since_rptDate__mean_by_acctType_credit_card",
#                     "trade_months_since_rptDate__mean_by_prtfType_mortgage",
#                     "trade_months_since_rptDate__sum_by_acctType_auto",
#                     "trade_number_CO_24_months__mean",
#                     "trade_number_DQ30_12_months__mean",
#                     "trade_number_DQ30_24_months__max",
#                     "trade_number_DQ30_24_months__max_by_prtfType_installment",
#                     "trade_number_DQ30_24_months__mean_by_acctType_auto",
#                     "trade_number_DQ30_24_months__mean_by_ecoa_individual",
#                     "trade_number_DQ30_24_months__mean_by_prtfType_installment",
#                     "trade_number_DQ30_24_months__sum",
#                     "trade_number_DQ30_6_months__max",
#                     "trade_number_DQ30_6_months__mean",
#                     "trade_number_DQ60_24_months__mean_by_acctType_auto",
#                     "trade_number_DQ60_24_months__mean_by_prtfType_installment",
#                     "trade_number_DQ60_24_months__sum",
#                     "trade_number_DQ90_24_months__mean_by_prtfType_installment",
#                     "trade_number_DQ90_24_months__sum",
#                     "trade_percent_CO_24_months__mean",
#                     "trade_percent_CO_24_months__min_by_ecoa_individual",
#                     "trade_percent_CO_24_months__min_by_prtfType_installment",
#                     "trade_percent_DQ30_12_months__max",
#                     "trade_percent_DQ30_12_months__max_by_prtfType_installment",
#                     "trade_percent_DQ30_12_months__mean",
#                     "trade_percent_DQ30_12_months__mean_by_prtfType_installment",
#                     "trade_percent_DQ30_24_months__max",
#                     "trade_percent_DQ30_24_months__mean",
#                     "trade_percent_DQ30_24_months__mean_by_prtfType_installment",
#                     "trade_percent_DQ30_6_months__max",
#                     "trade_percent_DQ30_6_months__mean",
#                     "trade_percent_DQ30_6_months__mean_by_ecoa_individual",
#                     "trade_percent_DQ30_6_months__mean_by_prtfType_installment",
#                     "trade_percent_DQ60_12_months__mean",
#                     "trade_pstDueAmt__mean",
#                     "trade_pstDueAmt__sum",
#                     "trade_pstDueAmt_accts_opened_12m__mean",
#                     "trade_pstDueAmt_accts_with_rcntPmt__min",
#                     "trade_pstDueAmt_active_accts__mean_by_acctType_auto",
#                     "trade_pstDueAmt_active_accts__min_by_acctType_auto",
#                     "trade_pstDueAmt_all_derog_accts__max_by_ecoa_individual",
#                     "trade_pstDueAmt_all_derog_accts__mean",
#                     "trade_pstDueAmt_all_derog_accts__mean_by_acctType_auto",
#                     "trade_pstDueAmt_all_derog_accts__min",
#                     "trade_pstDueAmt_all_derog_accts__min_by_acctType_auto",
#                     "trade_pstDueAmt_all_non_derog_accts__max",
#                     "trade_pstDueAmt_all_non_derog_accts__mean",
#                     "trade_pstDueAmt_with_crdUtl_gt_1__mean",
#                     "trade_pstDueAmt_with_crdUtl_gt_1__mean_by_ecoa_individual",
#                     "trade_pstDueAmt_with_crdUtl_gt_1__min",
#                     "trade_pstDue_to_blnc__mean",
#                     "trade_pstDue_to_blnc__mean_by_ecoa_individual",
#                     "trade_pstDue_to_blnc__min_by_acctType_auto",
#                     "trade_pstDue_to_blnc_accts_never_dq__max_by_ecoa_joint",
#                     "trade_pstDue_to_blnc_active_accts__max",
#                     "trade_pstDue_to_blnc_all_derog_accts__mean",
#                     "trade_pstDue_to_blnc_all_derog_accts__min",
#                     "trade_pstDue_to_blnc_all_derog_accts__min_by_ecoa_individual"
#                 ],
#                 "memory_efficient": true
#             }
#         },
#         "inq": {
#             "asset": "equifax/cms_6/inquiry.json",
#             "data": "#/home/lyt/CLIENTS/client-project-penfed/modeling/client_models/sample_files/inq_sampled_files.json",
#             "io_params": {
#                 "drop_duplicates": true,
#                 "keep_features": [
#                     "inq_inquiries__count_by_indCode_auto_mortgage",
#                     "inq_inquiries__count_by_month__max",
#                     "inq_inquiries__count_by_month__mean",
#                     "inq_inquiries__sum",
#                     "inq_inquiries_in_last_3_months__sum",
#                     "inq_inquiries_in_last_6_months__sum",
#                     "inq_inquiries_in_last_9_months__sum",
#                     "inq_inquiries_in_last_month__sum",
#                     "inq_inquiries_in_last_year__sum",
#                     "inq_months_since_INQUIRY_DATE__max",
#                     "inq_months_since_INQUIRY_DATE__mean",
#                     "inq_months_since_INQUIRY_DATE__min",
#                     "inq_months_since_INQUIRY_DATE__sum"
#                 ],
#                 "memory_efficient": true
#             }
#         },
#         "collec": {
#             "asset": "equifax/cms_6/collections.json",
#             "data": "#/home/lyt/CLIENTS/client-project-penfed/modeling/client_models/sample_files/collec_sampled_files.json",
#             "io_params": {
#                 "drop_duplicates": true,
#                 "keep_features": [
#                     "collec_blnc__sum",
#                     "collec_months_since_collection_opened__min",
#                     "collec___count",
#                     "collec_ratio_paid__max",
#                     "collec_ratio_paid__min"
#                 ],
#                 "memory_efficient": true
#             }
#         },
#         "bnkr": {
#             "asset": "equifax/cms_6/bankruptcy.json",
#             "data": "#/home/lyt/CLIENTS/client-project-penfed/modeling/client_models/sample_files/bnkr_sampled_files.json",
#             "io_params": {
#                 "drop_duplicates": true,
#                 "keep_features": [
#                     "bnkr___count",
#                     "bnkr___count_by_type_chapter_13_discharged",
#                     "bnkr___count_by_type_chapter_13_dismissed",
#                     "bnkr___count_by_type_chapter_7_discharged",
#                     "bnkr___count_by_type_chapter_7_dismissed",
#                     "bnkr_months_since_date_filed__max",
#                     "bnkr_months_since_date_filed__mean",
#                     "bnkr_months_since_date_filed__min"
#                 ],
#                 "memory_efficient": true
#             }
#         },
#         "member": {
#             "asset": "equifax/cms_6/member.json",
#             "data": "#/home/lyt/CLIENTS/client-project-penfed/modeling/client_models/sample_files/member_sampled_files.json",
#             "io_params": {
#                 "drop_duplicates": true,
#                 "keep_features": [
#                     "member_hcAmt_accts_never_dq__mean",
#                     "member_hcAmt__max_by_prtfType_revolving",
#                     "member_hcAmt__max_by_prtfType_installment",
#                     "member_hcAmt__sum_by_prtfType_installment",
#                     "member_hcAmt_accts_never_dq__max_by_prtfType_installment",
#                     "member_hcAmt_accts_never_dq__max_by_prtfType_revolving",
#                     "member_hcAmt_accts_opened_12m__sum_by_prtfType_installment",
#                     "member_hcAmt_accts_opened_12m__sum_by_prtfType_revolving",
#                     "member_hcAmt_active_accts__sum_by_prtfType_installment",
#                     "member_hcAmt_active_accts__sum_by_prtfType_revolving",
#                     "member_months_since_openDate__max_by_ecoa_individual",
#                     "member_hcAmt_active_accts__mean_by_ecoa_individual",
#                     "member_blnc_to_hc__max_by_prtfType_revolving",
#                     "member_blnc_to_hc__max_by_prtfType_installment",
#                     "member_blnc_to_hc_accts_never_dq__max_by_prtfType_revolving",
#                     "member_blnc_to_hc_accts_never_dq__max_by_prtfType_installment",
#                     "member_months_since_openDate__min",
#                     "member_months_since_openDate__max",
#                     "member_months_since_openDate__mean",
#                     "member_number_DQ60_24_months__sum",
#                     "member_number_DQ30_24_months__sum",
#                     "member_number_DQ60_12_months__sum",
#                     "member_number_DQ30_12_months__sum",
#                     "member_number_CO_24_months__sum",
#                     "member_acctType__count",
#                     "member_blncAmt__sum_by_acctType_unsecure",
#                     "member_blncAmt__sum_by_prtfType_revolving",
#                     "member_blncAmt__sum_by_prtfType_installment"
#                 ],
#                 "memory_efficient": true
#             }
#         },
#         "app": {
#             "asset": {
#                 "info": {
#                     "key": "ZEST_KEY",
#                     "app_date": "appDate"
#                 },
#                 "table_name": "app",
#                 "table_type": "one_to_one",
#                 "feature_engineering": "one_to_one"
#             },
#             "data": "#/home/lyt/CLIENTS/client-project-penfed/modeling/client_models/sample_files/app_sampled_files.json",
#             "io_params": {
#                 "drop_duplicates": true,
#                 "keep_features": [
#                     "appDate",
#                     "is_client",
#                     "bisgWhite",
#                     "bisgBlack",
#                     "bisgAian",
#                     "bisgApi",
#                     "bisgHispanic",
#                     "bisgMulti",
#                     "prob_male",
#                     "prob_female",
#                     "prob_<62",
#                     "prob_62+",
#                     "VS30",
#                     "VS40",
#                     "perf_state_cde",
#                     "perf_acct_typ_cde",
#                     "kob",
#                     "flg_exist_fe_trade",
#                     "ZEST_KEY"
#                 ],
#                 "memory_efficient": true
#             }
#         },
#         "target": {
#             "asset": {
#                 "info": {
#                     "col": "final_DQ60_m24",
#                     "key": "ZEST_KEY"
#                 },
#                 "table_type": "target"
#             },
#             "data": "#/home/lyt/CLIENTS/client-project-penfed/modeling/client_models/sample_files/target_sampled_files.json",
#             "io_params": {
#                 "drop_duplicates": true,
#                 "keep_features": [
#                     "ZEST_KEY",
#                     "final_DQ60_m24"
#                 ],
#                 "memory_efficient": true
#             }
#         },
#         "client_data": {
#             "data": "#/home/lyt/CLIENTS/client-project-penfed/modeling/client_models/sample_files/client_data_sampled_files.json",
#             "asset": {
#                 "feature_engineering": "one_to_one",
#                 "validator": "base",
#                 "table_type": "app",
#                 "info": {
#                     "key": "ZEST_KEY",
#                     "numerics": [
#                         "LTV_NORM"
#                     ]
#                 }
#             }
#         }
#     },
#     "config": {
#         "data_split": {
#             "train": {
#                 "start_date": "2019-04-01",
#                 "end_date": "2022-03-13"
#             },
#             "valid": {
#                 "start_date": "2022-03-13",
#                 "end_date": "2022-07-28"
#             },
#             "test": {
#                 "start_date": "2022-07-28",
#                 "end_date": "2023-03-31"
#             }
#         },
#         "target": "final_DQ60_m24",
#         "base_features": "/d/shared/users/lyt/penfed_poc1_national_models/nationalmodel2a/keep_features.json",
#         "memory_efficient": true,
#         "pipeline_factory": "LargeClientPipelineFactory",
#         "bivariate_fe_instructions": [],
#         "monotonic_constraints_list": [
#             {
#                 "feature": "client_data_LTV_NORM",
#                 "monotonic_constraint": "positive"
#             }
#         ],
#         "exclusion_list": [],
#         "feature_definition_list": [
#             {
#                 "feature": "client_data_LTV_NORM",
#                 "definition": "Customer has either calculated the following feature(s) based on its internal policies, or provided Zest with the underlying data and logic to compute the features, and requested that Zest include it in the model: Customer has either calculated the following feature(s) based on its internal policies, or provided Zest with the underlying data and logic to compute the features, and requested that Zest include it in the model: Customer has either calculated the following feature(s) based on its internal policies, or provided Zest with the underlying data and logic to compute the features, and requested that Zest include it in the model: Customer has either calculated the following feature(s) based on its internal policies, or provided Zest with the underlying data and logic to compute the features, and requested that Zest include it in the model: Customer has either calculated the following feature(s) based on its internal policies, or provided Zest with the underlying data and logic to compute the features, and requested that Zest include it in the model: loan to value"
#             }
#         ],
#         "key_factor_mapping_list": [
#             {
#                 "feature": "client_data_LTV_NORM",
#                 "key_factor": "Deal structure"
#             }
#         ],
#         "fold_valid": false,
#         "mandatory_features": []
#     }
# }

# %%
from model_engine.model_builder import build_model

output = build_model.build_model(asset, final_model_output_path)
# Out:
# parsing model-builder asset
# WARNING:py.warnings:Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 11.0.0, and the legacy implementation will be removed in a future version.
#
# WARNING:py.warnings:Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 11.0.0, and the legacy implementation will be removed in a future version.
#
# WARNING:py.warnings:Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 11.0.0, and the legacy implementation will be removed in a future version.
#
# WARNING:py.warnings:Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 11.0.0, and the legacy implementation will be removed in a future version.
#
# WARNING:py.warnings:Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 11.0.0, and the legacy implementation will be removed in a future version.
#
# WARNING:py.warnings:Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 11.0.0, and the legacy implementation will be removed in a future version.
#
# WARNING:py.warnings:Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 11.0.0, and the legacy implementation will be removed in a future version.
#
# WARNING:py.warnings:Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 11.0.0, and the legacy implementation will be removed in a future version.
# Configuring model builder
# WARNING:zaml.artifact_engine.logger:target is given but is not an expected input.
# WARNING:zaml.artifact_engine.logger:base_features is given but is not an expected input.
# WARNING:zaml.artifact_engine.logger:memory_efficient is given but is not an expected input.
# WARNING:zaml.artifact_engine.logger:fold_valid is given but is not an expected input.
# WARNING:zaml.artifact_engine.logger:mandatory_features is given but is not an expected input.
# INFO:zaml.artifact_engine.logger:Executing InputArtifact <input_asset>...
# INFO:zaml.artifact_engine.logger:Executing InputArtifact <input_data>...
# INFO:zaml.artifact_engine.logger:Executing InputArtifact <monotonic_constraints_list>...
# INFO:zaml.artifact_engine.logger:Executing InputArtifact <data_split>...
# INFO:zaml.artifact_engine.logger:Executing InputArtifact <train_sample_weight>...
# INFO:zaml.artifact_engine.logger:Not all required inputs are available for optional artifact <train_sample_weight>, thus it will be omitted.
# INFO:zaml.artifact_engine.logger:Executing InputArtifact <valid_sample_weight>...
# INFO:zaml.artifact_engine.logger:Not all required inputs are available for optional artifact <valid_sample_weight>, thus it will be omitted.
# INFO:zaml.artifact_engine.logger:Executing InputArtifact <test_sample_weight>...
# INFO:zaml.artifact_engine.logger:Not all required inputs are available for optional artifact <test_sample_weight>, thus it will be omitted.
# INFO:zaml.artifact_engine.logger:Executing InputArtifact <n_tiers>...
# INFO:zaml.artifact_engine.logger:Not all required inputs are available for optional artifact <n_tiers>, thus it will be omitted.
# INFO:zaml.artifact_engine.logger:Executing InputArtifact <feature_definition_list>...
# INFO:zaml.artifact_engine.logger:Executing InputArtifact <key_factor_mapping_list>...
# INFO:zaml.artifact_engine.logger:Executing InputArtifact <value_based_key_factor_mapping_list>...
# INFO:zaml.artifact_engine.logger:Not all required inputs are available for optional artifact <value_based_key_factor_mapping_list>, thus it will be omitted.
# INFO:zaml.artifact_engine.logger:Executing InputArtifact <exclusion_list>...
# INFO:zaml.artifact_engine.logger:Executing InputArtifact <bivariate_fe_instructions>...
# INFO:zaml.artifact_engine.logger:Executing InputArtifact <neutralization_list>...
# INFO:zaml.artifact_engine.logger:Not all required inputs are available for optional artifact <neutralization_list>, thus it will be omitted.
# INFO:zaml.artifact_engine.logger:Executing InputArtifact <pipeline_factory>...
# INFO:zaml.artifact_engine.logger:Executing InputAssetArtifact <asset>...
# INFO:zaml.artifact_engine.logger:Finished <asset>, total time spent: 0:00:00.001534
# INFO:zaml.artifact_engine.logger:Executing Versions <versions>...
# building model
# INFO:zaml.artifact_engine.logger:Finished <versions>, total time spent: 0:00:06.547975
# INFO:zaml.artifact_engine.logger:Executing MonotonicConstraintsListParser <parsed_monotonic_constraints_list>...
# INFO:zaml.artifact_engine.logger:Finished <parsed_monotonic_constraints_list>, total time spent: 0:00:01.293793
# INFO:zaml.artifact_engine.logger:Executing SplitterArtifact <splitter>...
# INFO:zaml.artifact_engine.logger:Finished <splitter>, total time spent: 0:00:00.000747
# INFO:zaml.artifact_engine.logger:Executing DataArtifact <data>...
# INFO:zaml.artifact_engine.logger:Finished <data>, total time spent: 0:00:00.000550
# INFO:zaml.artifact_engine.logger:Executing ExclusionListParser <parsed_exclusion_list>...
# INFO:zaml.artifact_engine.logger:Finished <parsed_exclusion_list>, total time spent: 0:00:00.000732
# INFO:zaml.artifact_engine.logger:Executing BivariateFeParser <parsed_biv_fe_instructions>...
# INFO:zaml.artifact_engine.logger:Finished <parsed_biv_fe_instructions>, total time spent: 0:00:00.000673
# INFO:zaml.artifact_engine.logger:Executing NeutralizationListParser <parsed_neutralization_list>...
# INFO:zaml.artifact_engine.logger:Not all required inputs are available for optional artifact <parsed_neutralization_list>, thus it will be omitted.
# INFO:zaml.artifact_engine.logger:Finished <parsed_neutralization_list>, total time spent: 0:00:00.001200
# INFO:zaml.artifact_engine.logger:Executing SeriesArtifact <target>...
# INFO:zaml.artifact_engine.logger:Finished <target>, total time spent: 0:00:00.007001
# INFO:zaml.artifact_engine.logger:Executing AppArtifact <app>...
# INFO:zaml.artifact_engine.logger:Finished <app>, total time spent: 0:00:00.008973
# INFO:zaml.artifact_engine.logger:Executing PipeFactoryConfigArtifact <pipe_factory_config>...
# INFO:zaml.artifact_engine.logger:Finished <pipe_factory_config>, total time spent: 0:00:00.172202
# INFO:zaml.artifact_engine.logger:Executing FitParamsArtifact <fit_params>...
# INFO:zaml.artifact_engine.logger:Finished <fit_params>, total time spent: 0:00:00.000739
# INFO:zaml.artifact_engine.logger:Executing DataDictGenerator <data_dict>...
# INFO:zaml.artifact_engine.logger:Finished <data_dict>, total time spent: 0:00:00.002880
# INFO:zaml.artifact_engine.logger:Executing CatMapGenerator <cat_map>...
# INFO:zaml.artifact_engine.logger:Finished <cat_map>, total time spent: 0:00:00.002238
# INFO:zaml.artifact_engine.logger:Executing AppDateSeries <app_date_series>...
# INFO:zaml.artifact_engine.logger:Finished <app_date_series>, total time spent: 0:00:00.010673
# INFO:zaml.artifact_engine.logger:Executing SplitDataCollectionArtifact <split_target_collection>...
# WARNING:py.warnings:Target has different length with app data.
#
# INFO:zaml.artifact_engine.logger:Finished <split_target_collection>, total time spent: 0:00:01.656168
# INFO:zaml.artifact_engine.logger:Executing SplitDataCollectionArtifact <split_app_collection>...
# INFO:zaml.artifact_engine.logger:Finished <split_app_collection>, total time spent: 0:00:00.419784
# INFO:zaml.artifact_engine.logger:Executing SplitDataCollectionArtifact <split_data_collection>...
# INFO:zaml.artifact_engine.logger:Finished <split_data_collection>, total time spent: 0:00:21.854858
# INFO:zaml.artifact_engine.logger:Executing SplitDataArtifact <train_target>...
# INFO:zaml.artifact_engine.logger:Finished <train_target>, total time spent: 0:00:00.000699
# INFO:zaml.artifact_engine.logger:Executing SplitDataArtifact <train_app>...
# INFO:zaml.artifact_engine.logger:Finished <train_app>, total time spent: 0:00:00.000549
# INFO:zaml.artifact_engine.logger:Executing SplitDataArtifact <valid_target>...
# INFO:zaml.artifact_engine.logger:Finished <valid_target>, total time spent: 0:00:00.000380
# INFO:zaml.artifact_engine.logger:Executing SplitDataArtifact <valid_app>...
# INFO:zaml.artifact_engine.logger:Finished <valid_app>, total time spent: 0:00:00.000658
# INFO:zaml.artifact_engine.logger:Executing SplitDataArtifact <test_target>...
# INFO:zaml.artifact_engine.logger:Finished <test_target>, total time spent: 0:00:00.000605
# INFO:zaml.artifact_engine.logger:Executing SplitDataArtifact <test_app>...
# INFO:zaml.artifact_engine.logger:Finished <test_app>, total time spent: 0:00:00.000343
# INFO:zaml.artifact_engine.logger:Executing SplitDataArtifact <train_data>...
# INFO:zaml.artifact_engine.logger:Finished <train_data>, total time spent: 0:00:00.000316
# INFO:zaml.artifact_engine.logger:Executing SplitDataArtifact <valid_data>...
# INFO:zaml.artifact_engine.logger:Finished <valid_data>, total time spent: 0:00:00.000596
# INFO:zaml.artifact_engine.logger:Executing SplitDataArtifact <test_data>...
# INFO:zaml.artifact_engine.logger:Finished <test_data>, total time spent: 0:00:00.000476
# INFO:zaml.artifact_engine.logger:Executing SplitDataSummary <train_data_summary>...
# INFO:zaml.artifact_engine.logger:Finished <train_data_summary>, total time spent: 0:00:03.555730
# INFO:zaml.artifact_engine.logger:Executing SplitDataSummary <valid_data_summary>...
# INFO:zaml.artifact_engine.logger:Finished <valid_data_summary>, total time spent: 0:00:01.442642
# INFO:zaml.artifact_engine.logger:Executing SplitDataSummary <test_data_summary>...
# INFO:zaml.artifact_engine.logger:Finished <test_data_summary>, total time spent: 0:00:02.433027
# INFO:zaml.artifact_engine.logger:Executing PipeFitter <pipeline_fitter>...
# -------------------------
# Name: app
# Transformer type: None
# Number of features: 18
# Time spent: 0.028s
# -------------------------
# Name: bnkr
# Transformer type: None
# Number of features: 8
# Time spent: 0.017s
# -------------------------
# Name: client_data
# Transformer type: None
# Number of features: 431
# Time spent: 0.018s
# -------------------------
# Name: collec
# Transformer type: None
# Number of features: 5
# Time spent: 0.017s
# -------------------------
# Name: inq
# Transformer type: None
# Number of features: 13
# Time spent: 0.017s
# -------------------------
# Name: member
# Transformer type: None
# Number of features: 28
# Time spent: 0.022s
# -------------------------
# Name: trade
# Transformer type: None
# Number of features: 216
# Time spent: 0.036s
# -------------------------
# Name: app FE
# Transformer type: OneToOneEngine
# Number of features: 0
# Time spent: 0.059s
# -------------------------
# Name: bnkr FE
# Transformer type: ManyToOneEngine
# Number of features: 8
# Time spent: 0.051s
# -------------------------
# Name: client_data FE
# Transformer type: OneToOneEngine
# Number of features: 1
# Time spent: 106.112s
# -------------------------
# Name: collec FE
# Transformer type: ManyToOneEngine
# Number of features: 5
# Time spent: 0.050s
# -------------------------
# Name: inq FE
# Transformer type: InquiryFeatureEngine
# Number of features: 13
# Time spent: 0.061s
# -------------------------
# Name: member FE
# Transformer type: TradelineFeatureEngine
# Number of features: 28
# Time spent: 0.083s
# -------------------------
# Name: trade FE
# Transformer type: TradelineFeatureEngine
# Number of features: 216
# Time spent: 0.278s
# -------------------------
# Name: Merge data
# Transformer type: Concat
# Number of features: 271
# Time spent: 3.494s
# -------------------------
# Name: OneHotEncoder
# Transformer type: OneHotEncoder
# Number of features: 271
# Time spent: 0.026s
# WARNING:py.warnings:No blacklisted columns were found in dataframe.
#
# WARNING:py.warnings:`dropped_features_` is empty. Input dataframe is returned.
# -------------------------
# Name: FillNA
# Transformer type: FillNA
# Number of features: 271
# Time spent: 5.275s
# -------------------------
# Name: GeneralFeatureSelection
# Transformer type: GeneralFeatureSelection
# Number of features: 271
# Time spent: 0.003s
# [0]	train-auc:0.72165	val-auc:0.72013
# [100]	train-auc:0.76834	val-auc:0.76367
# [200]	train-auc:0.77289	val-auc:0.76792
# [300]	train-auc:0.77778	val-auc:0.77315
# [400]	train-auc:0.78152	val-auc:0.77699
# [500]	train-auc:0.78522	val-auc:0.78072
# [600]	train-auc:0.78773	val-auc:0.78311
# [700]	train-auc:0.79037	val-auc:0.78549
# [800]	train-auc:0.79251	val-auc:0.78737
# [900]	train-auc:0.79439	val-auc:0.78899
# [1000]	train-auc:0.79587	val-auc:0.79012
# [1100]	train-auc:0.79728	val-auc:0.79134
# [1200]	train-auc:0.79857	val-auc:0.79229
# [1300]	train-auc:0.79978	val-auc:0.79301
# [1400]	train-auc:0.80072	val-auc:0.79357
# [1500]	train-auc:0.80163	val-auc:0.79421
# [1600]	train-auc:0.80246	val-auc:0.79468
# [1700]	train-auc:0.80322	val-auc:0.79520
# [1800]	train-auc:0.80401	val-auc:0.79565
# [1900]	train-auc:0.80466	val-auc:0.79599
# [2000]	train-auc:0.80535	val-auc:0.79627
# [2100]	train-auc:0.80598	val-auc:0.79664
# [2200]	train-auc:0.80653	val-auc:0.79688
# [2300]	train-auc:0.80700	val-auc:0.79704
# [2400]	train-auc:0.80756	val-auc:0.79729
# [2500]	train-auc:0.80806	val-auc:0.79749
# [2600]	train-auc:0.80860	val-auc:0.79775
# [2700]	train-auc:0.80908	val-auc:0.79796
# [2800]	train-auc:0.80954	val-auc:0.79812
# [2900]	train-auc:0.81003	val-auc:0.79833
# [3000]	train-auc:0.81052	val-auc:0.79850
# [3100]	train-auc:0.81096	val-auc:0.79860
# [3200]	train-auc:0.81139	val-auc:0.79873
# [3300]	train-auc:0.81180	val-auc:0.79887
# [3400]	train-auc:0.81221	val-auc:0.79901
# [3500]	train-auc:0.81259	val-auc:0.79910
# [3600]	train-auc:0.81295	val-auc:0.79913
# [3700]	train-auc:0.81333	val-auc:0.79927
# [3800]	train-auc:0.81368	val-auc:0.79932
# [3900]	train-auc:0.81407	val-auc:0.79942
# [4000]	train-auc:0.81442	val-auc:0.79947
# [4100]	train-auc:0.81474	val-auc:0.79956
# [4200]	train-auc:0.81510	val-auc:0.79962
# [4300]	train-auc:0.81541	val-auc:0.79969
# [4400]	train-auc:0.81576	val-auc:0.79975
# [4500]	train-auc:0.81612	val-auc:0.79979
# [4600]	train-auc:0.81643	val-auc:0.79984
# [4700]	train-auc:0.81674	val-auc:0.79990
# [4800]	train-auc:0.81708	val-auc:0.79997
# [4900]	train-auc:0.81739	val-auc:0.79994
# [5000]	train-auc:0.81769	val-auc:0.79993
# [5018]	train-auc:0.81775	val-auc:0.79995
# INFO:zaml.artifact_engine.logger:Finished <pipeline_fitter>, total time spent: 0:25:38.526669
# INFO:zaml.artifact_engine.logger:Executing FittedPipeline <pipeline>...
# INFO:zaml.artifact_engine.logger:Finished <pipeline>, total time spent: 0:00:00.000814
# INFO:zaml.artifact_engine.logger:Executing FitTimeInfoArtifact <fit_time_info>...
# INFO:zaml.artifact_engine.logger:Finished <fit_time_info>, total time spent: 0:00:00.000471
# INFO:zaml.artifact_engine.logger:Executing PipeFactoryArtifact <pipe_factory>...
# INFO:zaml.artifact_engine.logger:Finished <pipe_factory>, total time spent: 0:00:00.000439
# INFO:zaml.artifact_engine.logger:Executing FittedModel <model>...
# INFO:zaml.artifact_engine.logger:Finished <model>, total time spent: 0:00:00.000280
# INFO:zaml.artifact_engine.logger:Executing FeDataArtifact <train_fe_data>...
# -------------------------
# Name: app
# Transformer type: None
# Number of features: 18
# Time spent: 0.000s
# -------------------------
# Name: bnkr
# Transformer type: None
# Number of features: 8
# Time spent: 0.000s
# -------------------------
# Name: client_data
# Transformer type: None
# Number of features: 431
# Time spent: 0.001s
# -------------------------
# Name: collec
# Transformer type: None
# Number of features: 5
# Time spent: 0.000s
# -------------------------
# Name: inq
# Transformer type: None
# Number of features: 13
# Time spent: 0.000s
# -------------------------
# Name: member
# Transformer type: None
# Number of features: 28
# Time spent: 0.000s
# -------------------------
# Name: trade
# Transformer type: None
# Number of features: 216
# Time spent: 0.000s
# -------------------------
# Name: app FE
# Transformer type: OneToOneEngine
# Number of features: 0
# Time spent: 0.030s
# -------------------------
# Name: bnkr FE
# Transformer type: ManyToOneEngine
# Number of features: 8
# Time spent: 0.018s
# -------------------------
# Name: client_data FE
# Transformer type: OneToOneEngine
# Number of features: 1
# Time spent: 32.504s
# -------------------------
# Name: collec FE
# Transformer type: ManyToOneEngine
# Number of features: 5
# Time spent: 0.020s
# -------------------------
# Name: inq FE
# Transformer type: InquiryFeatureEngine
# Number of features: 13
# Time spent: 0.024s
# -------------------------
# Name: member FE
# Transformer type: TradelineFeatureEngine
# Number of features: 28
# Time spent: 0.035s
# -------------------------
# Name: trade FE
# Transformer type: TradelineFeatureEngine
# Number of features: 216
# Time spent: 0.152s
# -------------------------
# Name: Merge data
# Transformer type: Concat
# Number of features: 271
# Time spent: 3.678s
# -------------------------
# Name: OneHotEncoder
# Transformer type: OneHotEncoder
# Number of features: 271
# Time spent: 0.000s
# WARNING:py.warnings:`dropped_features_` is empty. Input dataframe is returned.
#
# INFO:zaml.artifact_engine.logger:Finished <train_fe_data>, total time spent: 0:00:39.249499
# INFO:zaml.artifact_engine.logger:Executing FeDataArtifact <valid_fe_data>...
# -------------------------
# Name: FillNA
# Transformer type: FillNA
# Number of features: 271
# Time spent: 2.785s
# -------------------------
# Name: GeneralFeatureSelection
# Transformer type: GeneralFeatureSelection
# Number of features: 271
# Time spent: 0.001s
# -------------------------
# Name: app
# Transformer type: None
# Number of features: 18
# Time spent: 0.000s
# -------------------------
# Name: bnkr
# Transformer type: None
# Number of features: 8
# Time spent: 0.000s
# -------------------------
# Name: client_data
# Transformer type: None
# Number of features: 431
# Time spent: 0.000s
# -------------------------
# Name: collec
# Transformer type: None
# Number of features: 5
# Time spent: 0.000s
# -------------------------
# Name: inq
# Transformer type: None
# Number of features: 13
# Time spent: 0.000s
# -------------------------
# Name: member
# Transformer type: None
# Number of features: 28
# Time spent: 0.000s
# -------------------------
# Name: trade
# Transformer type: None
# Number of features: 216
# Time spent: 0.000s
# -------------------------
# Name: app FE
# Transformer type: OneToOneEngine
# Number of features: 0
# Time spent: 0.022s
# -------------------------
# Name: bnkr FE
# Transformer type: ManyToOneEngine
# Number of features: 8
# Time spent: 0.017s
# -------------------------
# Name: client_data FE
# Transformer type: OneToOneEngine
# Number of features: 1
# Time spent: 18.114s
# -------------------------
# Name: collec FE
# Transformer type: ManyToOneEngine
# Number of features: 5
# Time spent: 0.018s
# -------------------------
# Name: inq FE
# Transformer type: InquiryFeatureEngine
# Number of features: 13
# Time spent: 0.021s
# -------------------------
# Name: member FE
# Transformer type: TradelineFeatureEngine
# Number of features: 28
# Time spent: 0.029s
# -------------------------
# Name: trade FE
# Transformer type: TradelineFeatureEngine
# Number of features: 216
# Time spent: 0.088s
# -------------------------
# Name: Merge data
# Transformer type: Concat
# Number of features: 271
# Time spent: 1.753s
# -------------------------
# Name: OneHotEncoder
# Transformer type: OneHotEncoder
# Number of features: 271
# Time spent: 0.000s
# WARNING:py.warnings:`dropped_features_` is empty. Input dataframe is returned.
#
# INFO:zaml.artifact_engine.logger:Finished <valid_fe_data>, total time spent: 0:00:22.668708
# -------------------------
# Name: FillNA
# Transformer type: FillNA
# Number of features: 271
# Time spent: 2.402s
# -------------------------
# Name: GeneralFeatureSelection
# Transformer type: GeneralFeatureSelection
# Number of features: 271
# Time spent: 0.001s
# INFO:zaml.artifact_engine.logger:Executing FeDataArtifact <test_fe_data>...
# -------------------------
# Name: app
# Transformer type: None
# Number of features: 18
# Time spent: 0.000s
# -------------------------
# Name: bnkr
# Transformer type: None
# Number of features: 8
# Time spent: 0.000s
# -------------------------
# Name: client_data
# Transformer type: None
# Number of features: 431
# Time spent: 0.000s
# -------------------------
# Name: collec
# Transformer type: None
# Number of features: 5
# Time spent: 0.000s
# -------------------------
# Name: inq
# Transformer type: None
# Number of features: 13
# Time spent: 0.000s
# -------------------------
# Name: member
# Transformer type: None
# Number of features: 28
# Time spent: 0.000s
# -------------------------
# Name: trade
# Transformer type: None
# Number of features: 216
# Time spent: 0.000s
# -------------------------
# Name: app FE
# Transformer type: OneToOneEngine
# Number of features: 0
# Time spent: 0.027s
# -------------------------
# Name: bnkr FE
# Transformer type: ManyToOneEngine
# Number of features: 8
# Time spent: 0.017s
# -------------------------
# Name: client_data FE
# Transformer type: OneToOneEngine
# Number of features: 1
# Time spent: 24.790s
# -------------------------
# Name: collec FE
# Transformer type: ManyToOneEngine
# Number of features: 5
# Time spent: 0.019s
# -------------------------
# Name: inq FE
# Transformer type: InquiryFeatureEngine
# Number of features: 13
# Time spent: 0.024s
# -------------------------
# Name: member FE
# Transformer type: TradelineFeatureEngine
# Number of features: 28
# Time spent: 0.034s
# -------------------------
# Name: trade FE
# Transformer type: TradelineFeatureEngine
# Number of features: 216
# Time spent: 0.162s
# -------------------------
# Name: Merge data
# Transformer type: Concat
# Number of features: 271
# Time spent: 3.112s
# -------------------------
# Name: OneHotEncoder
# Transformer type: OneHotEncoder
# Number of features: 271
# Time spent: 0.000s
# WARNING:py.warnings:`dropped_features_` is empty. Input dataframe is returned.
#
# INFO:zaml.artifact_engine.logger:Finished <test_fe_data>, total time spent: 0:00:31.324095
# -------------------------
# Name: FillNA
# Transformer type: FillNA
# Number of features: 271
# Time spent: 2.763s
# -------------------------
# Name: GeneralFeatureSelection
# Transformer type: GeneralFeatureSelection
# Number of features: 271
# Time spent: 0.001s
# INFO:zaml.artifact_engine.logger:Executing StaticAssetArtifact <static_asset>...
# INFO:zaml.artifact_engine.logger:Finished <static_asset>, total time spent: 0:00:02.241517
# INFO:zaml.artifact_engine.logger:Executing TrainHistoryArtifact <train_history>...
# INFO:zaml.artifact_engine.logger:Finished <train_history>, total time spent: 0:00:00.000855
# INFO:zaml.artifact_engine.logger:Executing BestModelParamsArtifact <best_model_params>...
# INFO:zaml.artifact_engine.logger:Finished <best_model_params>, total time spent: 0:00:00.000526
# INFO:zaml.artifact_engine.logger:Executing ScoresArtifact <train_scores>...
# INFO:zaml.artifact_engine.logger:Finished <train_scores>, total time spent: 0:00:00.996155
# INFO:zaml.artifact_engine.logger:Executing SubmodelScoresArtifact <train_submodel_scores>...
# INFO:zaml.artifact_engine.logger:Finished <train_submodel_scores>, total time spent: 0:00:00.000623
# INFO:zaml.artifact_engine.logger:Executing ScoresArtifact <valid_scores>...
# INFO:zaml.artifact_engine.logger:Finished <valid_scores>, total time spent: 0:00:00.580555
# INFO:zaml.artifact_engine.logger:Executing SubmodelScoresArtifact <valid_submodel_scores>...
# INFO:zaml.artifact_engine.logger:Finished <valid_submodel_scores>, total time spent: 0:00:00.000604
# INFO:zaml.artifact_engine.logger:Executing ScoresArtifact <test_scores>...
# INFO:zaml.artifact_engine.logger:Finished <test_scores>, total time spent: 0:00:00.833460
# INFO:zaml.artifact_engine.logger:Executing SubmodelScoresArtifact <test_submodel_scores>...
# INFO:zaml.artifact_engine.logger:Finished <test_submodel_scores>, total time spent: 0:00:00.000778
# INFO:zaml.artifact_engine.logger:Executing CalibrationObjectArtifact <calibration_object>...
# INFO:zaml.artifact_engine.logger:Finished <calibration_object>, total time spent: 0:00:01.861323
# INFO:zaml.artifact_engine.logger:Executing FeatureDefinition <feature_definition>...
# WARNING:py.warnings:Features: {'client_data_LTV_NORM'} do not have valid definitions!
#
# INFO:zaml.artifact_engine.logger:Finished <feature_definition>, total time spent: 0:00:00.785152
# INFO:zaml.artifact_engine.logger:Executing KeyFactorMapping <key_factors_mapping>...
# INFO:zaml.artifact_engine.logger:Finished <key_factors_mapping>, total time spent: 0:00:00.000991
# INFO:zaml.artifact_engine.logger:Executing ValueBasedKeyFactorMapping <value_based_key_factor_mapping>...
# INFO:zaml.artifact_engine.logger:Finished <value_based_key_factor_mapping>, total time spent: 0:00:00.000783
# INFO:zaml.artifact_engine.logger:Executing FeatureImportanceArtifact <feature_importance>...
# WARNING:py.warnings:Downsampling reference population to 3000 rows for Interventional Shapley
#
# WARNING:py.warnings:Downsampling explain population to 3000 rows for Interventional Shapley
#
# INFO:zaml.artifact_engine.logger:Finished <feature_importance>, total time spent: 0:00:11.532534
# INFO:zaml.artifact_engine.logger:Executing SubmodelFeatureImportanceArtifact <submodel_feature_importance>...
# INFO:zaml.artifact_engine.logger:Finished <submodel_feature_importance>, total time spent: 0:00:00.000659
# INFO:zaml.artifact_engine.logger:Executing ModelStrategy <model_strategy>...
# INFO:zaml.artifact_engine.logger:Finished <model_strategy>, total time spent: 0:00:00.000704
# INFO:zaml.artifact_engine.logger:Executing MRMPipeline <mrm_pipeline>...
# INFO:zaml.artifact_engine.logger:Finished <mrm_pipeline>, total time spent: 0:00:00.417789
# INFO:zaml.artifact_engine.logger:Executing PerformanceArtifact <train_auc>...
# INFO:zaml.artifact_engine.logger:Finished <train_auc>, total time spent: 0:00:00.663978
# INFO:zaml.artifact_engine.logger:Executing PerformanceArtifact <train_ks>...
# INFO:zaml.artifact_engine.logger:Finished <train_ks>, total time spent: 0:00:00.705600
# INFO:zaml.artifact_engine.logger:Executing SubmodelPerformanceArtifact <train_submodel_auc>...
# INFO:zaml.artifact_engine.logger:Finished <train_submodel_auc>, total time spent: 0:00:00.000709
# INFO:zaml.artifact_engine.logger:Executing SubmodelPerformanceArtifact <train_submodel_ks>...
# INFO:zaml.artifact_engine.logger:Finished <train_submodel_ks>, total time spent: 0:00:00.000583
# INFO:zaml.artifact_engine.logger:Executing PerformanceArtifact <valid_auc>...
# INFO:zaml.artifact_engine.logger:Finished <valid_auc>, total time spent: 0:00:00.251794
# INFO:zaml.artifact_engine.logger:Executing PerformanceArtifact <valid_ks>...
# INFO:zaml.artifact_engine.logger:Finished <valid_ks>, total time spent: 0:00:00.254725
# INFO:zaml.artifact_engine.logger:Executing SubmodelPerformanceArtifact <valid_submodel_auc>...
# INFO:zaml.artifact_engine.logger:Finished <valid_submodel_auc>, total time spent: 0:00:00.000625
# INFO:zaml.artifact_engine.logger:Executing SubmodelPerformanceArtifact <valid_submodel_ks>...
# INFO:zaml.artifact_engine.logger:Finished <valid_submodel_ks>, total time spent: 0:00:00.000659
# INFO:zaml.artifact_engine.logger:Executing PerformanceArtifact <test_auc>...
# INFO:zaml.artifact_engine.logger:Finished <test_auc>, total time spent: 0:00:00.366624
# INFO:zaml.artifact_engine.logger:Executing PerformanceArtifact <test_ks>...
# INFO:zaml.artifact_engine.logger:Finished <test_ks>, total time spent: 0:00:00.372174
# INFO:zaml.artifact_engine.logger:Executing SubmodelPerformanceArtifact <test_submodel_auc>...
# INFO:zaml.artifact_engine.logger:Finished <test_submodel_auc>, total time spent: 0:00:00.000706
# INFO:zaml.artifact_engine.logger:Executing SubmodelPerformanceArtifact <test_submodel_ks>...
# INFO:zaml.artifact_engine.logger:Finished <test_submodel_ks>, total time spent: 0:00:00.000645
# INFO:zaml.artifact_engine.logger:Executing CalibrationMapping <score_recalibration_mapping>...
# INFO:zaml.artifact_engine.logger:Finished <score_recalibration_mapping>, total time spent: 0:00:00.065271
# INFO:zaml.artifact_engine.logger:Executing TopFeaturesArtifact <top_features>...
# INFO:zaml.artifact_engine.logger:Finished <top_features>, total time spent: 0:00:00.002780
# INFO:zaml.artifact_engine.logger:Executing KeepFeatures <keep_features>...
# INFO:zaml.artifact_engine.logger:Finished <keep_features>, total time spent: 0:00:00.000739
# INFO:zaml.artifact_engine.logger:Executing SplitCalibratedScores <train_zest_scores>...
# INFO:zaml.artifact_engine.logger:Finished <train_zest_scores>, total time spent: 0:00:00.125914
# INFO:zaml.artifact_engine.logger:Executing SplitCalibratedScores <valid_zest_scores>...
# INFO:zaml.artifact_engine.logger:Finished <valid_zest_scores>, total time spent: 0:00:00.059693
# INFO:zaml.artifact_engine.logger:Executing SplitCalibratedScores <test_zest_scores>...
# INFO:zaml.artifact_engine.logger:Finished <test_zest_scores>, total time spent: 0:00:00.099274
# ERROR:zaml.artifact_engine.logger:`artifacts_pool` is not empty after a traversal. Remaining items are ['base_features', 'memory_efficient', 'fold_valid', 'mandatory_features'].

# %%
scoreFiles = []

for j in ['_auc.json','_ks.json']:
#     for i in ['train', 'valid', 'test']:
    for i in ['train','test',]:
        scoreFiles.append(i+j)
        
scoreFiles_model = {}
for i in scoreFiles:
    name = i.split('.')[0]
    # print(name)
    scoreFiles_model[name] = json.load(open(os.path.join(final_model_output_path, i), 'rb'))


for i in scoreFiles_model:
    print(i, scoreFiles_model[i])
# Out:
# train_auc {'auc': 0.8171497555770163}
# test_auc {'auc': 0.7891536188819329}
# train_ks {'ks': 0.48093953737844547}
# test_ks {'ks': 0.43269926748764576}

# %%
final_model_output_path
# Out:
# '/d/shared/silver_projects_v2/origencepocv2/autoloanv1/modeling/model_artifacts/autoloan/clientmodel3a'

# %% [markdown]
# ## 2. Fold valid Model

# %%
fold_valid_model_id = 'clientmodel3b'
fold_valid_model_output_path = f'/d/shared/silver_projects_v2/origencepocv2/autoloanv1/modeling/model_artifacts/autoloan/{fold_valid_model_id}'
fold_valid_model_output_path
# Out:
# '/d/shared/silver_projects_v2/origencepocv2/autoloanv1/modeling/model_artifacts/autoloan/clientmodel3b'

# %%
base_model_id = 'clientmodel3a'
asset = json.load(open(f'/d/shared/silver_projects_v2/origencepocv2/autoloanv1/modeling/model_artifacts/autoloan/{base_model_id}/asset.json'))
keep_features = json.load(open(f'/d/shared/silver_projects_v2/origencepocv2/autoloanv1/modeling/model_artifacts/autoloan/{base_model_id}/keep_features.json'))
best_ntree = json.load(open(f'/d/shared/silver_projects_v2/origencepocv2/autoloanv1/modeling/model_artifacts/autoloan/{base_model_id}/best_model_params.json'))
best_ntree['best_ntree_limit']
# Out:
# 4819

# %%
asset['config']['data_split']
# Out:
# {'train': {'start_date': '2019-04-01', 'end_date': '2022-03-13'},
#  'valid': {'start_date': '2022-03-13', 'end_date': '2022-07-28'},
#  'test': {'start_date': '2022-07-28', 'end_date': '2023-03-31'}}

# %%
asset['config']['data_split'] = {
    'train': {'start_date': '2019-04-01', 'end_date': '2022-07-28'},
    'test': {'start_date': '2022-07-28', 'end_date': '2023-03-31'}}

# %%
asset['config']['pipeline_factory'] =  {
      "transformers": [
        {
          "zaml_class": "LevelSelection",
          "params": {
            "thresh": 0.01,
            "change_to": "Other",
            "encoding": "onehot"
          }
        },
        {
          "zaml_class": "FillNA",
          "params": {
            "replace_by": -1,
            "add_flags": False
          }
        },
        {
          "zaml_class": "GeneralFeatureSelection",
          "params": {
            "features": [
              "app_is_client"
            ]
          }
        }
      ],
      "model": {
        "zaml_class": "XGBoostModel",
        "params": {
          "n_estimators": best_ntree['best_ntree_limit'],
          "learning_rate": 0.01,
          "max_depth": 3,
          "subsample": 0.5,
          "scale_pos_weight": 2.5,
          "colsample_bytree": 0.05,
          "min_child_weight": 350,
          "seed": 12,
          "eval_metric": "auc"
        }
      }
    }

# %%
asset['config']['pipeline_factory']['model']['params']['n_estimators']
# Out:
# 4819

# %%
asset['config'].pop('mandatory_features')
asset['config']['fold_valid'] = True
asset['config']['enforce_artifact_validation'] = True
asset['config']['base_features'] = f'/d/shared/silver_projects_v2/origencepocv2/autoloanv1/modeling/model_artifacts/autoloan/{base_model_id}/keep_features.json'

# %%
for t, l in keep_features.items():
    print(t)
    if t != 'client_data': 
        asset['data'][t]['io_params']['keep_features'] = l
    else: 
        continue
# Out:
# trade
# inq
# collec
# bnkr
# member
# client_data

# %%
asset['data']['app']
# Out:
# {'asset': {'info': {'key': 'ZEST_KEY', 'app_date': 'appDate'},
#   'table_name': 'app',
#   'table_type': 'one_to_one',
#   'feature_engineering': 'one_to_one'},
#  'data': '#/home/lyt/CLIENTS/client-project-penfed/modeling/client_models/sample_files/app_sampled_files.json',
#  'io_params': {'drop_duplicates': True,
#   'keep_features': ['appDate',
#    'is_client',
#    'bisgWhite',
#    'bisgBlack',
#    'bisgAian',
#    'bisgApi',
#    'bisgHispanic',
#    'bisgMulti',
#    'prob_male',
#    'prob_female',
#    'prob_<62',
#    'prob_62+',
#    'VS30',
#    'VS40',
#    'perf_state_cde',
#    'perf_acct_typ_cde',
#    'kob',
#    'flg_exist_fe_trade',
#    'ZEST_KEY'],
#   'memory_efficient': True}}

# %%
asset['data']['client_data']
# Out:
# {'data': '#/home/lyt/CLIENTS/client-project-penfed/modeling/client_models/sample_files/client_data_sampled_files.json',
#  'asset': {'feature_engineering': 'one_to_one',
#   'validator': 'base',
#   'table_type': 'app',
#   'info': {'key': 'ZEST_KEY', 'numerics': ['LTV_NORM']}}}

# %%
model_builder = ModelBuilder(asset)
model_builder.configure_run(fold_valid_model_output_path, 
                            cache=True) 

state = asset_parser(asset)

input_asset = (json.dumps(state['input_asset'], indent=4))
print(input_asset)
# Out:
# WARNING:py.warnings:Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 11.0.0, and the legacy implementation will be removed in a future version.
#
# WARNING:py.warnings:Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 11.0.0, and the legacy implementation will be removed in a future version.
#
# WARNING:py.warnings:Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 11.0.0, and the legacy implementation will be removed in a future version.
#
# WARNING:py.warnings:Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 11.0.0, and the legacy implementation will be removed in a future version.
#
# WARNING:py.warnings:Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 11.0.0, and the legacy implementation will be removed in a future version.
#
# WARNING:py.warnings:Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 11.0.0, and the legacy implementation will be removed in a future version.
#
# WARNING:py.warnings:Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 11.0.0, and the legacy implementation will be removed in a future version.
#
# WARNING:py.warnings:Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 11.0.0, and the legacy implementation will be removed in a future version.
#
# WARNING:py.warnings:Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 11.0.0, and the legacy implementation will be removed in a future version.
#
# WARNING:py.warnings:Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 11.0.0, and the legacy implementation will be removed in a future version.
#
# WARNING:py.warnings:Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 11.0.0, and the legacy implementation will be removed in a future version.
#
# WARNING:py.warnings:Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 11.0.0, and the legacy implementation will be removed in a future version.
#
# WARNING:py.warnings:Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 11.0.0, and the legacy implementation will be removed in a future version.
#
# WARNING:py.warnings:Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 11.0.0, and the legacy implementation will be removed in a future version.
#
# WARNING:py.warnings:Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 11.0.0, and the legacy implementation will be removed in a future version.
#
# WARNING:py.warnings:Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 11.0.0, and the legacy implementation will be removed in a future version.
# {
#     "data": {
#         "trade": {
#             "asset": "equifax/cms_6/trade.json",
#             "data": "#/home/lyt/CLIENTS/client-project-penfed/modeling/client_models/sample_files/trade_sampled_files.json",
#             "io_params": {
#                 "drop_duplicates": true,
#                 "keep_features": [
#                     "trade_acctType__count",
#                     "trade_blncAmt__mean_by_acctType_auto",
#                     "trade_blncAmt__min_by_acctType_education",
#                     "trade_blncAmt_accts_never_dq__max",
#                     "trade_blncAmt_accts_never_dq__max_by_ecoa_joint",
#                     "trade_blncAmt_accts_never_dq__max_by_prtfType_mortgage",
#                     "trade_blncAmt_accts_never_dq__mean_by_acctType_unsecure",
#                     "trade_blncAmt_accts_never_dq__mean_by_ecoa_joint",
#                     "trade_blncAmt_accts_never_dq__sum",
#                     "trade_blncAmt_accts_never_dq__sum_by_prtfType_mortgage",
#                     "trade_blncAmt_accts_opened_12m__max_by_ecoa_individual",
#                     "trade_blncAmt_accts_opened_12m__mean_by_ecoa_individual",
#                     "trade_blncAmt_accts_opened_12m__sum_by_acctType_unsecure",
#                     "trade_blncAmt_accts_opened_12m__sum_by_ecoa_individual",
#                     "trade_blncAmt_accts_with_rcntPmt__max",
#                     "trade_blncAmt_accts_with_rcntPmt__mean_by_acctType_credit_card",
#                     "trade_blncAmt_accts_with_rcntPmt__mean_by_acctType_education",
#                     "trade_blncAmt_accts_with_rcntPmt__mean_by_prtfType_revolving",
#                     "trade_blncAmt_accts_with_rcntPmt__min",
#                     "trade_blncAmt_accts_with_rcntPmt__min_by_ecoa_joint",
#                     "trade_blncAmt_accts_with_rcntPmt__min_by_prtfType_revolving",
#                     "trade_blncAmt_accts_with_rcntPmt__sum_by_acctType_education",
#                     "trade_blncAmt_active_accts__sum",
#                     "trade_blncAmt_active_accts__sum_by_prtfType_revolving",
#                     "trade_blncAmt_all_derog_accts__max",
#                     "trade_blncAmt_all_derog_accts__max_by_acctType_auto",
#                     "trade_blncAmt_all_derog_accts__max_by_ecoa_individual",
#                     "trade_blncAmt_all_derog_accts__max_by_prtfType_installment",
#                     "trade_blncAmt_all_derog_accts__mean",
#                     "trade_blncAmt_all_non_derog_accts__mean_by_acctType_auto",
#                     "trade_blncAmt_all_non_derog_accts__mean_by_ecoa_individual",
#                     "trade_blncAmt_all_non_derog_accts__mean_by_prtfType_revolving",
#                     "trade_blncAmt_with_crdUtl_gt_0.25__sum_by_ecoa_individual",
#                     "trade_blncAmt_with_crdUtl_gt_0.5__mean_by_ecoa_individual",
#                     "trade_blncAmt_with_crdUtl_gt_0.5__sum_by_ecoa_individual",
#                     "trade_blncAmt_with_crdUtl_gt_1__mean_by_ecoa_individual",
#                     "trade_blncAmt_with_hc_to_cl_gt_0.25__mean",
#                     "trade_blncAmt_with_hc_to_cl_gt_0.25__mean_by_ecoa_individual",
#                     "trade_blncAmt_with_hc_to_cl_gt_0.5__mean_by_ecoa_individual",
#                     "trade_blnc_to_hc__max_by_acctType_auto",
#                     "trade_blnc_to_hc__max_by_acctType_secure",
#                     "trade_blnc_to_hc__max_by_acctType_unsecure",
#                     "trade_blnc_to_hc__mean_by_acctType_unsecure",
#                     "trade_blnc_to_hc__mean_by_prtfType_revolving",
#                     "trade_blnc_to_hc_accts_never_dq__max_by_prtfType_mortgage",
#                     "trade_blnc_to_hc_accts_never_dq__min_by_prtfType_installment",
#                     "trade_blnc_to_hc_accts_opened_12m__max_by_acctType_secure",
#                     "trade_blnc_to_hc_accts_opened_12m__mean_by_prtfType_revolving",
#                     "trade_blnc_to_hc_accts_opened_12m__sum_by_acctType_unsecure",
#                     "trade_blnc_to_hc_accts_with_rcntPmt__max_by_acctType_auto",
#                     "trade_blnc_to_hc_accts_with_rcntPmt__max_by_prtfType_revolving",
#                     "trade_blnc_to_hc_accts_with_rcntPmt__mean_by_acctType_credit_card",
#                     "trade_blnc_to_hc_accts_with_rcntPmt__mean_by_prtfType_revolving",
#                     "trade_blnc_to_hc_accts_with_rcntPmt__min_by_prtfType_installment",
#                     "trade_blnc_to_hc_accts_with_rcntPmt__min_by_prtfType_revolving",
#                     "trade_blnc_to_hc_active_accts__max_by_acctType_secure",
#                     "trade_blnc_to_hc_active_accts__mean_by_acctType_credit_card",
#                     "trade_blnc_to_hc_active_accts__mean_by_prtfType_revolving",
#                     "trade_blnc_to_hc_all_non_derog_accts__max_by_prtfType_installment",
#                     "trade_blnc_to_hc_all_non_derog_accts__mean_by_acctType_auto",
#                     "trade_blnc_to_hc_all_non_derog_accts__mean_by_prtfType_installment",
#                     "trade_blnc_to_hc_all_non_derog_accts__min_by_prtfType_installment",
#                     "trade_blnc_to_hc_with_crdUtl_gt_0.25__max_by_prtfType_revolving",
#                     "trade_blnc_to_hc_with_crdUtl_gt_0.25__min_by_prtfType_revolving",
#                     "trade_blnc_to_hc_with_crdUtl_gt_0.5__max_by_prtfType_revolving",
#                     "trade_blnc_to_hc_with_hc_to_cl_gt_0.25__mean_by_prtfType_revolving",
#                     "trade_blnc_to_hc_with_hc_to_cl_gt_0.5__mean_by_prtfType_revolving",
#                     "trade_blnc_to_hc_with_hc_to_cl_gt_1__max_by_prtfType_revolving",
#                     "trade_blnc_to_hc_with_hc_to_cl_gt_1__mean_by_prtfType_revolving",
#                     "trade_clAmt__max_by_prtfType_revolving",
#                     "trade_clAmt__mean_by_acctType_credit_card",
#                     "trade_clAmt__mean_by_prtfType_revolving",
#                     "trade_clAmt_accts_never_dq__max_by_acctType_credit_card",
#                     "trade_clAmt_accts_never_dq__max_by_prtfType_revolving",
#                     "trade_clAmt_accts_never_dq__mean_by_acctType_credit_card",
#                     "trade_clAmt_accts_never_dq__min_by_acctType_credit_card",
#                     "trade_clAmt_accts_with_rcntPmt__max_by_prtfType_revolving",
#                     "trade_clAmt_accts_with_rcntPmt__mean_by_acctType_credit_card",
#                     "trade_clAmt_accts_with_rcntPmt__mean_by_prtfType_revolving",
#                     "trade_clAmt_accts_with_rcntPmt__min_by_prtfType_revolving",
#                     "trade_clAmt_accts_with_rcntPmt__sum_by_prtfType_revolving",
#                     "trade_clAmt_active_accts__max_by_prtfType_revolving",
#                     "trade_clAmt_active_accts__mean_by_acctType_credit_card",
#                     "trade_clAmt_active_accts__mean_by_prtfType_revolving",
#                     "trade_clAmt_active_accts__min_by_acctType_credit_card",
#                     "trade_clAmt_active_accts__min_by_prtfType_revolving",
#                     "trade_clAmt_all_non_derog_accts__max_by_acctType_credit_card",
#                     "trade_clAmt_all_non_derog_accts__max_by_prtfType_revolving",
#                     "trade_clAmt_all_non_derog_accts__mean_by_acctType_credit_card",
#                     "trade_clAmt_all_non_derog_accts__mean_by_prtfType_revolving",
#                     "trade_clAmt_with_hc_to_cl_gt_0.25__mean_by_prtfType_revolving",
#                     "trade_clAmt_with_hc_to_cl_gt_0.5__mean_by_prtfType_revolving",
#                     "trade_crdUtl__max_by_acctType_credit_card",
#                     "trade_crdUtl__max_by_prtfType_revolving",
#                     "trade_crdUtl__mean_by_prtfType_revolving",
#                     "trade_crdUtl_accts_opened_12m__max_by_prtfType_revolving",
#                     "trade_crdUtl_accts_with_rcntPmt__mean_by_prtfType_revolving",
#                     "trade_crdUtl_accts_with_rcntPmt__min_by_prtfType_revolving",
#                     "trade_crdUtl_active_accts__max_by_prtfType_revolving",
#                     "trade_crdUtl_active_accts__mean_by_prtfType_revolving",
#                     "trade_hcAmt__max_by_acctType_education",
#                     "trade_hcAmt__min_by_acctType_education",
#                     "trade_hcAmt__min_by_prtfType_installment",
#                     "trade_hcAmt_accts_never_dq__max_by_prtfType_mortgage",
#                     "trade_hcAmt_accts_never_dq__mean_by_prtfType_revolving",
#                     "trade_hcAmt_accts_never_dq__min_by_ecoa_joint",
#                     "trade_hcAmt_accts_never_dq__min_by_prtfType_installment",
#                     "trade_hcAmt_accts_never_dq__min_by_prtfType_mortgage",
#                     "trade_hcAmt_accts_never_dq__sum",
#                     "trade_hcAmt_accts_never_dq__sum_by_ecoa_joint",
#                     "trade_hcAmt_accts_never_dq__sum_by_prtfType_installment",
#                     "trade_hcAmt_accts_never_dq__sum_by_prtfType_mortgage",
#                     "trade_hcAmt_accts_with_rcntPmt__max_by_acctType_education",
#                     "trade_hcAmt_accts_with_rcntPmt__max_by_ecoa_joint",
#                     "trade_hcAmt_accts_with_rcntPmt__mean",
#                     "trade_hcAmt_accts_with_rcntPmt__mean_by_acctType_education",
#                     "trade_hcAmt_accts_with_rcntPmt__min",
#                     "trade_hcAmt_accts_with_rcntPmt__sum",
#                     "trade_hcAmt_accts_with_rcntPmt__sum_by_acctType_education",
#                     "trade_hcAmt_accts_with_rcntPmt__sum_by_ecoa_joint",
#                     "trade_hcAmt_all_derog_accts__max",
#                     "trade_hcAmt_all_derog_accts__max_by_acctType_auto",
#                     "trade_hcAmt_all_derog_accts__mean",
#                     "trade_hcAmt_all_derog_accts__min",
#                     "trade_hcAmt_all_derog_accts__sum_by_acctType_auto",
#                     "trade_hcAmt_all_non_derog_accts__max_by_ecoa_joint",
#                     "trade_hcAmt_all_non_derog_accts__max_by_prtfType_revolving",
#                     "trade_hcAmt_all_non_derog_accts__mean_by_prtfType_installment",
#                     "trade_hcAmt_all_non_derog_accts__mean_by_prtfType_revolving",
#                     "trade_hcAmt_all_non_derog_accts__sum",
#                     "trade_hcAmt_all_non_derog_accts__sum_by_ecoa_joint",
#                     "trade_hcAmt_all_non_derog_accts__sum_by_prtfType_mortgage",
#                     "trade_hcAmt_with_crdUtl_gt_0.5__sum_by_ecoa_individual",
#                     "trade_hc_to_cl_accts_opened_12m__max_by_acctType_credit_card",
#                     "trade_hc_to_cl_accts_opened_12m__max_by_prtfType_revolving",
#                     "trade_hc_to_cl_accts_with_rcntPmt__max_by_prtfType_revolving",
#                     "trade_hc_to_cl_accts_with_rcntPmt__mean_by_prtfType_revolving",
#                     "trade_hc_to_cl_accts_with_rcntPmt__min_by_prtfType_revolving",
#                     "trade_hc_to_cl_active_accts__max_by_prtfType_revolving",
#                     "trade_hc_to_cl_active_accts__min_by_prtfType_revolving",
#                     "trade_hc_to_cl_all_non_derog_accts__max_by_acctType_credit_card",
#                     "trade_hc_to_cl_all_non_derog_accts__min_by_acctType_credit_card",
#                     "trade_months_since_lstPmtDate__mean_by_acctType_education",
#                     "trade_months_since_lstPmtDate__min_by_acctType_education",
#                     "trade_months_since_lstPmtDate__min_by_prtfType_mortgage",
#                     "trade_months_since_lstPmtDate__min_by_prtfType_revolving",
#                     "trade_months_since_lstPmtDate__sum_by_acctType_education",
#                     "trade_months_since_openDate__max",
#                     "trade_months_since_openDate__max_by_acctType_auto",
#                     "trade_months_since_openDate__max_by_acctType_credit_card",
#                     "trade_months_since_openDate__max_by_ecoa_individual",
#                     "trade_months_since_openDate__max_by_ecoa_joint",
#                     "trade_months_since_openDate__max_by_prtfType_revolving",
#                     "trade_months_since_openDate__mean_by_acctType_auto",
#                     "trade_months_since_openDate__mean_by_acctType_credit_card",
#                     "trade_months_since_openDate__mean_by_ecoa_individual",
#                     "trade_months_since_openDate__mean_by_prtfType_installment",
#                     "trade_months_since_openDate__mean_by_prtfType_revolving",
#                     "trade_months_since_openDate__min_by_ecoa_individual",
#                     "trade_months_since_rptDate__mean_by_acctType_credit_card",
#                     "trade_months_since_rptDate__mean_by_prtfType_mortgage",
#                     "trade_months_since_rptDate__sum_by_acctType_auto",
#                     "trade_number_CO_24_months__mean",
#                     "trade_number_DQ30_12_months__mean",
#                     "trade_number_DQ30_24_months__max",
#                     "trade_number_DQ30_24_months__max_by_prtfType_installment",
#                     "trade_number_DQ30_24_months__mean_by_acctType_auto",
#                     "trade_number_DQ30_24_months__mean_by_ecoa_individual",
#                     "trade_number_DQ30_24_months__mean_by_prtfType_installment",
#                     "trade_number_DQ30_24_months__sum",
#                     "trade_number_DQ30_6_months__max",
#                     "trade_number_DQ30_6_months__mean",
#                     "trade_number_DQ60_24_months__mean_by_acctType_auto",
#                     "trade_number_DQ60_24_months__mean_by_prtfType_installment",
#                     "trade_number_DQ60_24_months__sum",
#                     "trade_number_DQ90_24_months__mean_by_prtfType_installment",
#                     "trade_number_DQ90_24_months__sum",
#                     "trade_percent_CO_24_months__mean",
#                     "trade_percent_CO_24_months__min_by_ecoa_individual",
#                     "trade_percent_CO_24_months__min_by_prtfType_installment",
#                     "trade_percent_DQ30_12_months__max",
#                     "trade_percent_DQ30_12_months__max_by_prtfType_installment",
#                     "trade_percent_DQ30_12_months__mean",
#                     "trade_percent_DQ30_12_months__mean_by_prtfType_installment",
#                     "trade_percent_DQ30_24_months__max",
#                     "trade_percent_DQ30_24_months__mean",
#                     "trade_percent_DQ30_24_months__mean_by_prtfType_installment",
#                     "trade_percent_DQ30_6_months__max",
#                     "trade_percent_DQ30_6_months__mean",
#                     "trade_percent_DQ30_6_months__mean_by_ecoa_individual",
#                     "trade_percent_DQ30_6_months__mean_by_prtfType_installment",
#                     "trade_percent_DQ60_12_months__mean",
#                     "trade_pstDueAmt__mean",
#                     "trade_pstDueAmt__sum",
#                     "trade_pstDueAmt_accts_opened_12m__mean",
#                     "trade_pstDueAmt_accts_with_rcntPmt__min",
#                     "trade_pstDueAmt_active_accts__mean_by_acctType_auto",
#                     "trade_pstDueAmt_active_accts__min_by_acctType_auto",
#                     "trade_pstDueAmt_all_derog_accts__max_by_ecoa_individual",
#                     "trade_pstDueAmt_all_derog_accts__mean",
#                     "trade_pstDueAmt_all_derog_accts__mean_by_acctType_auto",
#                     "trade_pstDueAmt_all_derog_accts__min",
#                     "trade_pstDueAmt_all_derog_accts__min_by_acctType_auto",
#                     "trade_pstDueAmt_all_non_derog_accts__max",
#                     "trade_pstDueAmt_all_non_derog_accts__mean",
#                     "trade_pstDueAmt_with_crdUtl_gt_1__mean",
#                     "trade_pstDueAmt_with_crdUtl_gt_1__mean_by_ecoa_individual",
#                     "trade_pstDueAmt_with_crdUtl_gt_1__min",
#                     "trade_pstDue_to_blnc__mean",
#                     "trade_pstDue_to_blnc__mean_by_ecoa_individual",
#                     "trade_pstDue_to_blnc__min_by_acctType_auto",
#                     "trade_pstDue_to_blnc_accts_never_dq__max_by_ecoa_joint",
#                     "trade_pstDue_to_blnc_active_accts__max",
#                     "trade_pstDue_to_blnc_all_derog_accts__mean",
#                     "trade_pstDue_to_blnc_all_derog_accts__min",
#                     "trade_pstDue_to_blnc_all_derog_accts__min_by_ecoa_individual"
#                 ],
#                 "memory_efficient": true
#             }
#         },
#         "inq": {
#             "asset": "equifax/cms_6/inquiry.json",
#             "data": "#/home/lyt/CLIENTS/client-project-penfed/modeling/client_models/sample_files/inq_sampled_files.json",
#             "io_params": {
#                 "drop_duplicates": true,
#                 "keep_features": [
#                     "inq_inquiries__count_by_indCode_auto_mortgage",
#                     "inq_inquiries__count_by_month__max",
#                     "inq_inquiries__count_by_month__mean",
#                     "inq_inquiries__sum",
#                     "inq_inquiries_in_last_3_months__sum",
#                     "inq_inquiries_in_last_6_months__sum",
#                     "inq_inquiries_in_last_9_months__sum",
#                     "inq_inquiries_in_last_month__sum",
#                     "inq_inquiries_in_last_year__sum",
#                     "inq_months_since_INQUIRY_DATE__max",
#                     "inq_months_since_INQUIRY_DATE__mean",
#                     "inq_months_since_INQUIRY_DATE__min",
#                     "inq_months_since_INQUIRY_DATE__sum"
#                 ],
#                 "memory_efficient": true
#             }
#         },
#         "collec": {
#             "asset": "equifax/cms_6/collections.json",
#             "data": "#/home/lyt/CLIENTS/client-project-penfed/modeling/client_models/sample_files/collec_sampled_files.json",
#             "io_params": {
#                 "drop_duplicates": true,
#                 "keep_features": [
#                     "collec_blnc__sum",
#                     "collec_months_since_collection_opened__min",
#                     "collec___count",
#                     "collec_ratio_paid__max",
#                     "collec_ratio_paid__min"
#                 ],
#                 "memory_efficient": true
#             }
#         },
#         "bnkr": {
#             "asset": "equifax/cms_6/bankruptcy.json",
#             "data": "#/home/lyt/CLIENTS/client-project-penfed/modeling/client_models/sample_files/bnkr_sampled_files.json",
#             "io_params": {
#                 "drop_duplicates": true,
#                 "keep_features": [
#                     "bnkr___count",
#                     "bnkr___count_by_type_chapter_13_discharged",
#                     "bnkr___count_by_type_chapter_13_dismissed",
#                     "bnkr___count_by_type_chapter_7_discharged",
#                     "bnkr___count_by_type_chapter_7_dismissed",
#                     "bnkr_months_since_date_filed__max",
#                     "bnkr_months_since_date_filed__mean",
#                     "bnkr_months_since_date_filed__min"
#                 ],
#                 "memory_efficient": true
#             }
#         },
#         "member": {
#             "asset": "equifax/cms_6/member.json",
#             "data": "#/home/lyt/CLIENTS/client-project-penfed/modeling/client_models/sample_files/member_sampled_files.json",
#             "io_params": {
#                 "drop_duplicates": true,
#                 "keep_features": [
#                     "member_hcAmt_accts_never_dq__mean",
#                     "member_hcAmt__max_by_prtfType_revolving",
#                     "member_hcAmt__max_by_prtfType_installment",
#                     "member_hcAmt__sum_by_prtfType_installment",
#                     "member_hcAmt_accts_never_dq__max_by_prtfType_installment",
#                     "member_hcAmt_accts_never_dq__max_by_prtfType_revolving",
#                     "member_hcAmt_accts_opened_12m__sum_by_prtfType_installment",
#                     "member_hcAmt_accts_opened_12m__sum_by_prtfType_revolving",
#                     "member_hcAmt_active_accts__sum_by_prtfType_installment",
#                     "member_hcAmt_active_accts__sum_by_prtfType_revolving",
#                     "member_months_since_openDate__max_by_ecoa_individual",
#                     "member_hcAmt_active_accts__mean_by_ecoa_individual",
#                     "member_blnc_to_hc__max_by_prtfType_revolving",
#                     "member_blnc_to_hc__max_by_prtfType_installment",
#                     "member_blnc_to_hc_accts_never_dq__max_by_prtfType_revolving",
#                     "member_blnc_to_hc_accts_never_dq__max_by_prtfType_installment",
#                     "member_months_since_openDate__min",
#                     "member_months_since_openDate__max",
#                     "member_months_since_openDate__mean",
#                     "member_number_DQ60_24_months__sum",
#                     "member_number_DQ30_24_months__sum",
#                     "member_number_DQ60_12_months__sum",
#                     "member_number_DQ30_12_months__sum",
#                     "member_number_CO_24_months__sum",
#                     "member_acctType__count",
#                     "member_blncAmt__sum_by_acctType_unsecure",
#                     "member_blncAmt__sum_by_prtfType_revolving",
#                     "member_blncAmt__sum_by_prtfType_installment"
#                 ],
#                 "memory_efficient": true
#             }
#         },
#         "app": {
#             "asset": {
#                 "info": {
#                     "key": "ZEST_KEY",
#                     "app_date": "appDate"
#                 },
#                 "table_name": "app",
#                 "table_type": "one_to_one",
#                 "feature_engineering": "one_to_one"
#             },
#             "data": "#/home/lyt/CLIENTS/client-project-penfed/modeling/client_models/sample_files/app_sampled_files.json",
#             "io_params": {
#                 "drop_duplicates": true,
#                 "keep_features": [
#                     "appDate",
#                     "is_client",
#                     "bisgWhite",
#                     "bisgBlack",
#                     "bisgAian",
#                     "bisgApi",
#                     "bisgHispanic",
#                     "bisgMulti",
#                     "prob_male",
#                     "prob_female",
#                     "prob_<62",
#                     "prob_62+",
#                     "VS30",
#                     "VS40",
#                     "perf_state_cde",
#                     "perf_acct_typ_cde",
#                     "kob",
#                     "flg_exist_fe_trade",
#                     "ZEST_KEY"
#                 ],
#                 "memory_efficient": true
#             }
#         },
#         "target": {
#             "asset": {
#                 "info": {
#                     "col": "final_DQ60_m24",
#                     "key": "ZEST_KEY"
#                 },
#                 "table_type": "target"
#             },
#             "data": "#/home/lyt/CLIENTS/client-project-penfed/modeling/client_models/sample_files/target_sampled_files.json",
#             "io_params": {
#                 "drop_duplicates": true,
#                 "keep_features": [
#                     "ZEST_KEY",
#                     "final_DQ60_m24"
#                 ],
#                 "memory_efficient": true
#             }
#         },
#         "client_data": {
#             "data": "#/home/lyt/CLIENTS/client-project-penfed/modeling/client_models/sample_files/client_data_sampled_files.json",
#             "asset": {
#                 "feature_engineering": "one_to_one",
#                 "validator": "base",
#                 "table_type": "app",
#                 "info": {
#                     "key": "ZEST_KEY",
#                     "numerics": [
#                         "LTV_NORM"
#                     ]
#                 }
#             }
#         }
#     },
#     "config": {
#         "data_split": {
#             "train": {
#                 "start_date": "2019-04-01",
#                 "end_date": "2022-07-28"
#             },
#             "test": {
#                 "start_date": "2022-07-28",
#                 "end_date": "2023-03-31"
#             }
#         },
#         "target": "final_DQ60_m24",
#         "base_features": "/d/shared/silver_projects_v2/origencepocv2/autoloanv1/modeling/model_artifacts/autoloan/clientmodel3a/keep_features.json",
#         "memory_efficient": true,
#         "pipeline_factory": {
#             "transformers": [
#                 {
#                     "zaml_class": "LevelSelection",
#                     "params": {
#                         "thresh": 0.01,
#                         "change_to": "Other",
#                         "encoding": "onehot"
#                     }
#                 },
#                 {
#                     "zaml_class": "FillNA",
#                     "params": {
#                         "replace_by": -1,
#                         "add_flags": false
#                     }
#                 },
#                 {
#                     "zaml_class": "GeneralFeatureSelection",
#                     "params": {
#                         "features": [
#                             "app_is_client"
#                         ]
#                     }
#                 }
#             ],
#             "model": {
#                 "zaml_class": "XGBoostModel",
#                 "params": {
#                     "n_estimators": 4819,
#                     "learning_rate": 0.01,
#                     "max_depth": 3,
#                     "subsample": 0.5,
#                     "scale_pos_weight": 2.5,
#                     "colsample_bytree": 0.05,
#                     "min_child_weight": 350,
#                     "seed": 12,
#                     "eval_metric": "auc"
#                 }
#             }
#         },
#         "bivariate_fe_instructions": [],
#         "monotonic_constraints_list": [
#             {
#                 "feature": "client_data_LTV_NORM",
#                 "monotonic_constraint": "positive"
#             }
#         ],
#         "exclusion_list": [],
#         "feature_definition_list": [
#             {
#                 "feature": "client_data_LTV_NORM",
#                 "definition": "Customer has either calculated the following feature(s) based on its internal policies, or provided Zest with the underlying data and logic to compute the features, and requested that Zest include it in the model: Customer has either calculated the following feature(s) based on its internal policies, or provided Zest with the underlying data and logic to compute the features, and requested that Zest include it in the model: Customer has either calculated the following feature(s) based on its internal policies, or provided Zest with the underlying data and logic to compute the features, and requested that Zest include it in the model: Customer has either calculated the following feature(s) based on its internal policies, or provided Zest with the underlying data and logic to compute the features, and requested that Zest include it in the model: Customer has either calculated the following feature(s) based on its internal policies, or provided Zest with the underlying data and logic to compute the features, and requested that Zest include it in the model: loan to value"
#             }
#         ],
#         "key_factor_mapping_list": [
#             {
#                 "feature": "client_data_LTV_NORM",
#                 "key_factor": "Deal structure"
#             }
#         ],
#         "fold_valid": true,
#         "enforce_artifact_validation": true
#     }
# }

# %%
with open (os.path.join(fold_valid_model_output_path, 'input_configuration.json'), 'w') as outfile:
    outfile.write(input_asset)

# %%
from model_engine.model_builder import build_model

output = build_model.build_model(asset, fold_valid_model_output_path)
# Out:
# parsing model-builder asset
# WARNING:py.warnings:Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 11.0.0, and the legacy implementation will be removed in a future version.
#
# WARNING:py.warnings:Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 11.0.0, and the legacy implementation will be removed in a future version.
#
# WARNING:py.warnings:Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 11.0.0, and the legacy implementation will be removed in a future version.
#
# WARNING:py.warnings:Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 11.0.0, and the legacy implementation will be removed in a future version.
#
# WARNING:py.warnings:Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 11.0.0, and the legacy implementation will be removed in a future version.
#
# WARNING:py.warnings:Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 11.0.0, and the legacy implementation will be removed in a future version.
#
# WARNING:py.warnings:Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 11.0.0, and the legacy implementation will be removed in a future version.
#
# WARNING:py.warnings:Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 11.0.0, and the legacy implementation will be removed in a future version.
# Configuring model builder
# WARNING:zaml.artifact_engine.logger:target is given but is not an expected input.
# WARNING:zaml.artifact_engine.logger:base_features is given but is not an expected input.
# WARNING:zaml.artifact_engine.logger:memory_efficient is given but is not an expected input.
# WARNING:zaml.artifact_engine.logger:fold_valid is given but is not an expected input.
# WARNING:zaml.artifact_engine.logger:enforce_artifact_validation is given but is not an expected input.
# INFO:zaml.artifact_engine.logger:Executing InputArtifact <input_asset>...
# INFO:zaml.artifact_engine.logger:Executing InputArtifact <input_data>...
# INFO:zaml.artifact_engine.logger:Executing InputArtifact <monotonic_constraints_list>...
# INFO:zaml.artifact_engine.logger:Executing InputArtifact <data_split>...
# INFO:zaml.artifact_engine.logger:Executing InputArtifact <train_sample_weight>...
# INFO:zaml.artifact_engine.logger:Not all required inputs are available for optional artifact <train_sample_weight>, thus it will be omitted.
# INFO:zaml.artifact_engine.logger:Executing InputArtifact <test_sample_weight>...
# INFO:zaml.artifact_engine.logger:Not all required inputs are available for optional artifact <test_sample_weight>, thus it will be omitted.
# INFO:zaml.artifact_engine.logger:Executing InputArtifact <n_tiers>...
# INFO:zaml.artifact_engine.logger:Not all required inputs are available for optional artifact <n_tiers>, thus it will be omitted.
# INFO:zaml.artifact_engine.logger:Executing InputArtifact <feature_definition_list>...
# INFO:zaml.artifact_engine.logger:Executing InputArtifact <key_factor_mapping_list>...
# INFO:zaml.artifact_engine.logger:Executing InputArtifact <value_based_key_factor_mapping_list>...
# INFO:zaml.artifact_engine.logger:Not all required inputs are available for optional artifact <value_based_key_factor_mapping_list>, thus it will be omitted.
# INFO:zaml.artifact_engine.logger:Executing InputArtifact <valid_app>...
# INFO:zaml.artifact_engine.logger:Not all required inputs are available for optional artifact <valid_app>, thus it will be omitted.
# INFO:zaml.artifact_engine.logger:Executing InputArtifact <valid_data>...
# INFO:zaml.artifact_engine.logger:Not all required inputs are available for optional artifact <valid_data>, thus it will be omitted.
# INFO:zaml.artifact_engine.logger:Executing InputArtifact <valid_target>...
# INFO:zaml.artifact_engine.logger:Not all required inputs are available for optional artifact <valid_target>, thus it will be omitted.
# INFO:zaml.artifact_engine.logger:Executing InputArtifact <valid_sample_weight>...
# INFO:zaml.artifact_engine.logger:Not all required inputs are available for optional artifact <valid_sample_weight>, thus it will be omitted.
# INFO:zaml.artifact_engine.logger:Executing InputArtifact <exclusion_list>...
# INFO:zaml.artifact_engine.logger:Executing InputArtifact <bivariate_fe_instructions>...
# INFO:zaml.artifact_engine.logger:Executing InputArtifact <neutralization_list>...
# INFO:zaml.artifact_engine.logger:Not all required inputs are available for optional artifact <neutralization_list>, thus it will be omitted.
# INFO:zaml.artifact_engine.logger:Executing InputArtifact <pipeline_factory>...
# INFO:zaml.artifact_engine.logger:Executing InputAssetArtifact <asset>...
# INFO:zaml.artifact_engine.logger:Finished <asset>, total time spent: 0:00:00.000252
# INFO:zaml.artifact_engine.logger:Executing Versions <versions>...
# INFO:zaml.artifact_engine.logger:Finished <versions>, total time spent: 0:00:00.000252
# INFO:zaml.artifact_engine.logger:Executing MonotonicConstraintsListParser <parsed_monotonic_constraints_list>...
# building model
# INFO:zaml.artifact_engine.logger:Finished <parsed_monotonic_constraints_list>, total time spent: 0:00:00.929544
# INFO:zaml.artifact_engine.logger:Executing SplitterArtifact <splitter>...
# INFO:zaml.artifact_engine.logger:Finished <splitter>, total time spent: 0:00:00.000866
# INFO:zaml.artifact_engine.logger:Executing DataArtifact <data>...
# INFO:zaml.artifact_engine.logger:Finished <data>, total time spent: 0:00:00.000762
# INFO:zaml.artifact_engine.logger:Executing ExclusionListParser <parsed_exclusion_list>...
# INFO:zaml.artifact_engine.logger:Finished <parsed_exclusion_list>, total time spent: 0:00:00.000428
# INFO:zaml.artifact_engine.logger:Executing BivariateFeParser <parsed_biv_fe_instructions>...
# INFO:zaml.artifact_engine.logger:Finished <parsed_biv_fe_instructions>, total time spent: 0:00:00.000290
# INFO:zaml.artifact_engine.logger:Executing NeutralizationListParser <parsed_neutralization_list>...
# INFO:zaml.artifact_engine.logger:Not all required inputs are available for optional artifact <parsed_neutralization_list>, thus it will be omitted.
# INFO:zaml.artifact_engine.logger:Finished <parsed_neutralization_list>, total time spent: 0:00:00.000574
# INFO:zaml.artifact_engine.logger:Executing SeriesArtifact <target>...
# INFO:zaml.artifact_engine.logger:Finished <target>, total time spent: 0:00:00.007013
# INFO:zaml.artifact_engine.logger:Executing AppArtifact <app>...
# INFO:zaml.artifact_engine.logger:Finished <app>, total time spent: 0:00:00.010074
# INFO:zaml.artifact_engine.logger:Executing PipeFactoryConfigArtifact <pipe_factory_config>...
# INFO:zaml.artifact_engine.logger:Finished <pipe_factory_config>, total time spent: 0:00:00.000360
# INFO:zaml.artifact_engine.logger:Executing FitParamsArtifact <fit_params>...
# INFO:zaml.artifact_engine.logger:Finished <fit_params>, total time spent: 0:00:00.000310
# INFO:zaml.artifact_engine.logger:Executing DataDictGenerator <data_dict>...
# INFO:zaml.artifact_engine.logger:Finished <data_dict>, total time spent: 0:00:00.001422
# INFO:zaml.artifact_engine.logger:Executing CatMapGenerator <cat_map>...
# INFO:zaml.artifact_engine.logger:Finished <cat_map>, total time spent: 0:00:00.001462
# INFO:zaml.artifact_engine.logger:Executing AppDateSeries <app_date_series>...
# INFO:zaml.artifact_engine.logger:Finished <app_date_series>, total time spent: 0:00:00.008505
# INFO:zaml.artifact_engine.logger:Executing SplitDataCollectionArtifact <split_target_collection>...
# WARNING:py.warnings:Target has different length with app data.
#
# INFO:zaml.artifact_engine.logger:Finished <split_target_collection>, total time spent: 0:00:01.848658
# INFO:zaml.artifact_engine.logger:Executing SplitDataCollectionArtifact <split_app_collection>...
# INFO:zaml.artifact_engine.logger:Finished <split_app_collection>, total time spent: 0:00:00.298153
# INFO:zaml.artifact_engine.logger:Executing SplitDataCollectionArtifact <split_data_collection>...
# INFO:zaml.artifact_engine.logger:Finished <split_data_collection>, total time spent: 0:00:20.764749
# INFO:zaml.artifact_engine.logger:Executing SplitDataArtifact <train_target>...
# INFO:zaml.artifact_engine.logger:Finished <train_target>, total time spent: 0:00:00.000543
# INFO:zaml.artifact_engine.logger:Executing SplitDataArtifact <train_app>...
# INFO:zaml.artifact_engine.logger:Finished <train_app>, total time spent: 0:00:00.000852
# INFO:zaml.artifact_engine.logger:Executing SplitDataArtifact <test_target>...
# INFO:zaml.artifact_engine.logger:Finished <test_target>, total time spent: 0:00:00.000535
# INFO:zaml.artifact_engine.logger:Executing SplitDataArtifact <test_app>...
# INFO:zaml.artifact_engine.logger:Finished <test_app>, total time spent: 0:00:00.000531
# INFO:zaml.artifact_engine.logger:Executing SplitDataArtifact <train_data>...
# INFO:zaml.artifact_engine.logger:Finished <train_data>, total time spent: 0:00:00.000373
# INFO:zaml.artifact_engine.logger:Executing SplitDataArtifact <test_data>...
# INFO:zaml.artifact_engine.logger:Finished <test_data>, total time spent: 0:00:00.000456
# INFO:zaml.artifact_engine.logger:Executing SplitDataSummary <train_data_summary>...
# INFO:zaml.artifact_engine.logger:Finished <train_data_summary>, total time spent: 0:00:06.798304
# INFO:zaml.artifact_engine.logger:Executing SplitDataSummary <test_data_summary>...
# INFO:zaml.artifact_engine.logger:Finished <test_data_summary>, total time spent: 0:00:02.748099
# INFO:zaml.artifact_engine.logger:Executing PipeFitter <pipeline_fitter>...
# -------------------------
# Name: app
# Transformer type: None
# Number of features: 18
# Time spent: 0.031s
# -------------------------
# Name: bnkr
# Transformer type: None
# Number of features: 8
# Time spent: 0.017s
# -------------------------
# Name: client_data
# Transformer type: None
# Number of features: 431
# Time spent: 0.017s
# -------------------------
# Name: collec
# Transformer type: None
# Number of features: 5
# Time spent: 0.016s
# -------------------------
# Name: inq
# Transformer type: None
# Number of features: 13
# Time spent: 0.016s
# -------------------------
# Name: member
# Transformer type: None
# Number of features: 28
# Time spent: 0.021s
# -------------------------
# Name: trade
# Transformer type: None
# Number of features: 216
# Time spent: 0.035s
# -------------------------
# Name: app FE
# Transformer type: OneToOneEngine
# Number of features: 0
# Time spent: 0.044s
# -------------------------
# Name: bnkr FE
# Transformer type: ManyToOneEngine
# Number of features: 8
# Time spent: 0.033s
# -------------------------
# Name: client_data FE
# Transformer type: OneToOneEngine
# Number of features: 1
# Time spent: 95.663s
# -------------------------
# Name: collec FE
# Transformer type: ManyToOneEngine
# Number of features: 5
# Time spent: 0.034s
# -------------------------
# Name: inq FE
# Transformer type: InquiryFeatureEngine
# Number of features: 13
# Time spent: 0.044s
# -------------------------
# Name: member FE
# Transformer type: TradelineFeatureEngine
# Number of features: 28
# Time spent: 0.061s
# -------------------------
# Name: trade FE
# Transformer type: TradelineFeatureEngine
# Number of features: 216
# Time spent: 0.243s
# -------------------------
# Name: Merge data
# Transformer type: Concat
# Number of features: 271
# Time spent: 3.907s
# -------------------------
# Name: LevelSelection
# Transformer type: LevelSelection
# Number of features: 271
# Time spent: 0.258s
# WARNING:py.warnings:No blacklisted columns were found in dataframe.
#
# WARNING:py.warnings:`dropped_features_` is empty. Input dataframe is returned.
# -------------------------
# Name: FillNA
# Transformer type: FillNA
# Number of features: 271
# Time spent: 3.087s
# -------------------------
# Name: GeneralFeatureSelection
# Transformer type: GeneralFeatureSelection
# Number of features: 271
# Time spent: 0.003s
# INFO:zaml.artifact_engine.logger:Finished <pipeline_fitter>, total time spent: 0:05:36.357785
# INFO:zaml.artifact_engine.logger:Executing FittedPipeline <pipeline>...
# INFO:zaml.artifact_engine.logger:Finished <pipeline>, total time spent: 0:00:00.001530
# INFO:zaml.artifact_engine.logger:Executing FitTimeInfoArtifact <fit_time_info>...
# INFO:zaml.artifact_engine.logger:Finished <fit_time_info>, total time spent: 0:00:00.000703
# INFO:zaml.artifact_engine.logger:Executing PipeFactoryArtifact <pipe_factory>...
# INFO:zaml.artifact_engine.logger:Finished <pipe_factory>, total time spent: 0:00:00.000677
# INFO:zaml.artifact_engine.logger:Executing FittedModel <model>...
# INFO:zaml.artifact_engine.logger:Finished <model>, total time spent: 0:00:00.000711
# INFO:zaml.artifact_engine.logger:Executing FeDataArtifact <train_fe_data>...
# -------------------------
# Name: app
# Transformer type: None
# Number of features: 18
# Time spent: 0.000s
# -------------------------
# Name: bnkr
# Transformer type: None
# Number of features: 8
# Time spent: 0.000s
# -------------------------
# Name: client_data
# Transformer type: None
# Number of features: 431
# Time spent: 0.000s
# -------------------------
# Name: collec
# Transformer type: None
# Number of features: 5
# Time spent: 0.000s
# -------------------------
# Name: inq
# Transformer type: None
# Number of features: 13
# Time spent: 0.000s
# -------------------------
# Name: member
# Transformer type: None
# Number of features: 28
# Time spent: 0.000s
# -------------------------
# Name: trade
# Transformer type: None
# Number of features: 216
# Time spent: 0.000s
# -------------------------
# Name: app FE
# Transformer type: OneToOneEngine
# Number of features: 0
# Time spent: 0.038s
# -------------------------
# Name: bnkr FE
# Transformer type: ManyToOneEngine
# Number of features: 8
# Time spent: 0.018s
# -------------------------
# Name: client_data FE
# Transformer type: OneToOneEngine
# Number of features: 1
# Time spent: 9.150s
# -------------------------
# Name: collec FE
# Transformer type: ManyToOneEngine
# Number of features: 5
# Time spent: 0.019s
# -------------------------
# Name: inq FE
# Transformer type: InquiryFeatureEngine
# Number of features: 13
# Time spent: 0.027s
# -------------------------
# Name: member FE
# Transformer type: TradelineFeatureEngine
# Number of features: 28
# Time spent: 0.041s
# -------------------------
# Name: trade FE
# Transformer type: TradelineFeatureEngine
# Number of features: 216
# Time spent: 0.211s
# -------------------------
# Name: Merge data
# Transformer type: Concat
# Number of features: 271
# Time spent: 5.646s
# -------------------------
# Name: LevelSelection
# Transformer type: LevelSelection
# Number of features: 271
# Time spent: 0.445s
# WARNING:py.warnings:`dropped_features_` is empty. Input dataframe is returned.
#
# INFO:zaml.artifact_engine.logger:Finished <train_fe_data>, total time spent: 0:00:18.806145
# INFO:zaml.artifact_engine.logger:Executing FeDataArtifact <test_fe_data>...
# -------------------------
# Name: FillNA
# Transformer type: FillNA
# Number of features: 271
# Time spent: 3.209s
# -------------------------
# Name: GeneralFeatureSelection
# Transformer type: GeneralFeatureSelection
# Number of features: 271
# Time spent: 0.001s
# -------------------------
# Name: app
# Transformer type: None
# Number of features: 18
# Time spent: 0.000s
# -------------------------
# Name: bnkr
# Transformer type: None
# Number of features: 8
# Time spent: 0.000s
# -------------------------
# Name: client_data
# Transformer type: None
# Number of features: 431
# Time spent: 0.000s
# -------------------------
# Name: collec
# Transformer type: None
# Number of features: 5
# Time spent: 0.000s
# -------------------------
# Name: inq
# Transformer type: None
# Number of features: 13
# Time spent: 0.000s
# -------------------------
# Name: member
# Transformer type: None
# Number of features: 28
# Time spent: 0.000s
# -------------------------
# Name: trade
# Transformer type: None
# Number of features: 216
# Time spent: 0.000s
# -------------------------
# Name: app FE
# Transformer type: OneToOneEngine
# Number of features: 0
# Time spent: 0.026s
# -------------------------
# Name: bnkr FE
# Transformer type: ManyToOneEngine
# Number of features: 8
# Time spent: 0.017s
# -------------------------
# Name: client_data FE
# Transformer type: OneToOneEngine
# Number of features: 1
# Time spent: 8.545s
# -------------------------
# Name: collec FE
# Transformer type: ManyToOneEngine
# Number of features: 5
# Time spent: 0.018s
# -------------------------
# Name: inq FE
# Transformer type: InquiryFeatureEngine
# Number of features: 13
# Time spent: 0.023s
# -------------------------
# Name: member FE
# Transformer type: TradelineFeatureEngine
# Number of features: 28
# Time spent: 0.030s
# -------------------------
# Name: trade FE
# Transformer type: TradelineFeatureEngine
# Number of features: 216
# Time spent: 0.121s
# -------------------------
# Name: Merge data
# Transformer type: Concat
# Number of features: 271
# Time spent: 2.930s
# -------------------------
# Name: LevelSelection
# Transformer type: LevelSelection
# Number of features: 271
# Time spent: 0.211s
# WARNING:py.warnings:`dropped_features_` is empty. Input dataframe is returned.
# -------------------------
# Name: FillNA
# Transformer type: FillNA
# Number of features: 271
# Time spent: 2.663s
# -------------------------
# Name: GeneralFeatureSelection
# Transformer type: GeneralFeatureSelection
# Number of features: 271
# Time spent: 0.001s
# INFO:zaml.artifact_engine.logger:Finished <test_fe_data>, total time spent: 0:00:14.929780
# INFO:zaml.artifact_engine.logger:Executing StaticAssetArtifact <static_asset>...
# INFO:zaml.artifact_engine.logger:Finished <static_asset>, total time spent: 0:00:02.223780
# INFO:zaml.artifact_engine.logger:Executing TrainHistoryArtifact <train_history>...
# INFO:zaml.artifact_engine.logger:Finished <train_history>, total time spent: 0:00:00.000629
# INFO:zaml.artifact_engine.logger:Executing BestModelParamsArtifact <best_model_params>...
# INFO:zaml.artifact_engine.logger:Finished <best_model_params>, total time spent: 0:00:00.000306
# INFO:zaml.artifact_engine.logger:Executing ScoresArtifact <train_scores>...
# INFO:zaml.artifact_engine.logger:Finished <train_scores>, total time spent: 0:00:01.321573
# INFO:zaml.artifact_engine.logger:Executing SubmodelScoresArtifact <train_submodel_scores>...
# INFO:zaml.artifact_engine.logger:Finished <train_submodel_scores>, total time spent: 0:00:00.000660
# INFO:zaml.artifact_engine.logger:Executing ScoresArtifact <test_scores>...
# INFO:zaml.artifact_engine.logger:Finished <test_scores>, total time spent: 0:00:00.836394
# INFO:zaml.artifact_engine.logger:Executing SubmodelScoresArtifact <test_submodel_scores>...
# INFO:zaml.artifact_engine.logger:Finished <test_submodel_scores>, total time spent: 0:00:00.000721
# INFO:zaml.artifact_engine.logger:Executing CalibrationObjectArtifact <calibration_object>...
# INFO:zaml.artifact_engine.logger:Finished <calibration_object>, total time spent: 0:00:02.429642
# INFO:zaml.artifact_engine.logger:Executing FeatureDefinition <feature_definition>...
# WARNING:py.warnings:Features: {'client_data_LTV_NORM'} do not have valid definitions!
#
# INFO:zaml.artifact_engine.logger:Finished <feature_definition>, total time spent: 0:00:00.619311
# INFO:zaml.artifact_engine.logger:Executing KeyFactorMapping <key_factors_mapping>...
# INFO:zaml.artifact_engine.logger:Finished <key_factors_mapping>, total time spent: 0:00:00.000955
# INFO:zaml.artifact_engine.logger:Executing ValueBasedKeyFactorMapping <value_based_key_factor_mapping>...
# INFO:zaml.artifact_engine.logger:Finished <value_based_key_factor_mapping>, total time spent: 0:00:00.000850
# INFO:zaml.artifact_engine.logger:Executing FeatureImportanceArtifact <feature_importance>...
# WARNING:py.warnings:Downsampling reference population to 3000 rows for Interventional Shapley
#
# WARNING:py.warnings:Downsampling explain population to 3000 rows for Interventional Shapley
#
# INFO:zaml.artifact_engine.logger:Finished <feature_importance>, total time spent: 0:00:14.212562
# INFO:zaml.artifact_engine.logger:Executing SubmodelFeatureImportanceArtifact <submodel_feature_importance>...
# INFO:zaml.artifact_engine.logger:Finished <submodel_feature_importance>, total time spent: 0:00:00.000988
# INFO:zaml.artifact_engine.logger:Executing ModelStrategy <model_strategy>...
# INFO:zaml.artifact_engine.logger:Finished <model_strategy>, total time spent: 0:00:00.000664
# INFO:zaml.artifact_engine.logger:Executing MRMPipeline <mrm_pipeline>...
# INFO:zaml.artifact_engine.logger:Finished <mrm_pipeline>, total time spent: 0:00:00.897799
# INFO:zaml.artifact_engine.logger:Executing PerformanceArtifact <train_auc>...
# INFO:zaml.artifact_engine.logger:Finished <train_auc>, total time spent: 0:00:00.980134
# INFO:zaml.artifact_engine.logger:Executing PerformanceArtifact <train_ks>...
# INFO:zaml.artifact_engine.logger:Finished <train_ks>, total time spent: 0:00:01.088451
# INFO:zaml.artifact_engine.logger:Executing SubmodelPerformanceArtifact <train_submodel_auc>...
# INFO:zaml.artifact_engine.logger:Finished <train_submodel_auc>, total time spent: 0:00:00.000659
# INFO:zaml.artifact_engine.logger:Executing SubmodelPerformanceArtifact <train_submodel_ks>...
# INFO:zaml.artifact_engine.logger:Finished <train_submodel_ks>, total time spent: 0:00:00.000424
# INFO:zaml.artifact_engine.logger:Executing PerformanceArtifact <test_auc>...
# INFO:zaml.artifact_engine.logger:Finished <test_auc>, total time spent: 0:00:00.407956
# INFO:zaml.artifact_engine.logger:Executing PerformanceArtifact <test_ks>...
# INFO:zaml.artifact_engine.logger:Finished <test_ks>, total time spent: 0:00:00.403859
# INFO:zaml.artifact_engine.logger:Executing SubmodelPerformanceArtifact <test_submodel_auc>...
# INFO:zaml.artifact_engine.logger:Finished <test_submodel_auc>, total time spent: 0:00:00.000849
# INFO:zaml.artifact_engine.logger:Executing SubmodelPerformanceArtifact <test_submodel_ks>...
# INFO:zaml.artifact_engine.logger:Finished <test_submodel_ks>, total time spent: 0:00:00.000634
# INFO:zaml.artifact_engine.logger:Executing CalibrationMapping <score_recalibration_mapping>...
# INFO:zaml.artifact_engine.logger:Finished <score_recalibration_mapping>, total time spent: 0:00:00.003024
# INFO:zaml.artifact_engine.logger:Executing TopFeaturesArtifact <top_features>...
# INFO:zaml.artifact_engine.logger:Finished <top_features>, total time spent: 0:00:00.002200
# INFO:zaml.artifact_engine.logger:Executing KeepFeatures <keep_features>...
# INFO:zaml.artifact_engine.logger:Finished <keep_features>, total time spent: 0:00:00.000602
# INFO:zaml.artifact_engine.logger:Executing SplitCalibratedScores <train_zest_scores>...
# INFO:zaml.artifact_engine.logger:Finished <train_zest_scores>, total time spent: 0:00:00.206872
# INFO:zaml.artifact_engine.logger:Executing SplitCalibratedScores <test_zest_scores>...
# INFO:zaml.artifact_engine.logger:Finished <test_zest_scores>, total time spent: 0:00:00.107544
# ERROR:zaml.artifact_engine.logger:`artifacts_pool` is not empty after a traversal. Remaining items are ['base_features', 'memory_efficient', 'fold_valid', 'enforce_artifact_validation'].

# %%
scoreFiles = []

for j in ['_auc.json','_ks.json']:
#     for i in ['train', 'valid', 'test']:
    for i in ['train','test',]:
        scoreFiles.append(i+j)
        
scoreFiles_model = {}
for i in scoreFiles:
    name = i.split('.')[0]
    # print(name)
    scoreFiles_model[name] = json.load(open(os.path.join(fold_valid_model_output_path, i), 'rb'))


for i in scoreFiles_model:
    print(i, scoreFiles_model[i])
# Out:
# train_auc {'auc': 0.8146341489135276}
# test_auc {'auc': 0.7909405307330996}
# train_ks {'ks': 0.47554843742987213}
# test_ks {'ks': 0.4350592974562803}

# %%
ftr_impt = pd.read_parquet('/d/shared/silver_projects_v2/origencepocv2/autoloanv1/modeling/model_artifacts/autoloan/clientmodel1b/feature_importance.parquet')
ftr_impt.head(10)
# Out:
#                                              feature  importance
# 0                               client_data_LTV_NORM    0.024505
# 1      inq_inquiries__count_by_indCode_auto_mortgage    0.007294
# 2  trade_months_since_openDate__mean_by_prtfType_...    0.005222
# 3  trade_hc_to_cl_all_non_derog_accts__max_by_acc...    0.004717
# 4                                 inq_inquiries__sum    0.004683
# 5  trade_months_since_openDate__mean_by_acctType_...    0.004357
# 6                   inq_inquiries_in_last_month__sum    0.004318
# 7  trade_hc_to_cl_accts_opened_12m__max_by_prtfTy...    0.004274
# 8  trade_clAmt_active_accts__mean_by_prtfType_rev...    0.004047
# 9  trade_clAmt_accts_with_rcntPmt__min_by_prtfTyp...    0.003816
