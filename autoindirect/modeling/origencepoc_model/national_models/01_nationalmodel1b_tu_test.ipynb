# %% [markdown]
# # National Model 1a
#
# - Equifax, TU, Experian National model
# - Features selection on national data
# - Time split on Equifax

# %% [markdown]
# The notebook covers all three steps for creatign a new national model; feature selection, validation model and fold-in model. depending on the applied use case, not each step may be necessary (e.g., if the feature selection does not change compaed to the previous interation, step 1 may be skipped, etc.

# %%
import pandas as pd
import numpy as np

import model_engine
model_engine.__version__
# Out:
# 'v1.13.0'

# %%
from model_engine.power.post_sale import NationalModelBuilder
from model_engine.io.loaders import load_json

import json
# Out:
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/zamlexplain/utils_compile.py:23: NumbaPendingDeprecationWarning: The 'pycc' module is pending deprecation. Replacement technology is being developed.
#
# Pending Deprecation in Numba 0.57.0. For more information please see: https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-the-numba-pycc-module
#   from numba.pycc import CC
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/shap/utils/_clustering.py:35: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def _pt_shuffle_rec(i, indexes, index_mask, partition_tree, M, pos):
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/shap/utils/_clustering.py:54: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def delta_minimization_order(all_masks, max_swap_size=100, num_passes=2):
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/shap/utils/_clustering.py:63: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def _reverse_window(order, start, length):
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/shap/utils/_clustering.py:69: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def _reverse_window_score_gain(masks, order, start, length):
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/shap/utils/_clustering.py:77: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def _mask_delta_score(m1, m2):
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/shap/links.py:5: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def identity(x):
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/shap/links.py:10: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def _identity_inverse(x):
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/shap/links.py:15: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def logit(x):
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/shap/links.py:20: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def _logit_inverse(x):
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/shap/utils/_masked_model.py:363: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def _build_fixed_single_output(averaged_outs, last_outs, outputs, batch_positions, varying_rows, num_varying_rows, link, linearizing_weights):
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/shap/utils/_masked_model.py:385: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def _build_fixed_multi_output(averaged_outs, last_outs, outputs, batch_positions, varying_rows, num_varying_rows, link, linearizing_weights):
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/shap/utils/_masked_model.py:428: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def _init_masks(cluster_matrix, M, indices_row_pos, indptr):
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/shap/utils/_masked_model.py:439: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def _rec_fill_masks(cluster_matrix, indices_row_pos, indptr, indices, M, ind):
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/shap/maskers/_tabular.py:186: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def _single_delta_mask(dind, masked_inputs, last_mask, data, x, noop_code):
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/shap/maskers/_tabular.py:197: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def _delta_masking(masks, x, curr_delta_inds, varying_rows_out,
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/shap/maskers/_image.py:175: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def _jit_build_partition_tree(xmin, xmax, ymin, ymax, zmin, zmax, total_ywidth, total_zwidth, M, clustering, q):
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/shap/explainers/_partition.py:676: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def lower_credit(i, value, M, values, clustering):
# The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
# The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
# WARNING:py.warnings:Setuptools is replacing distutils. Support for replacing an already imported distutils is deprecated. In the future, this condition will fail. Register concerns at https://github.com/pypa/setuptools/issues/new?template=distutils-deprecation.yml

# %%
import os
import numba as nb
n_jobs = os.getenv('CPU_LIMIT', default=-1)
n_jobs = 20
print(n_jobs)
nb.set_num_threads(n_jobs)
# Out:
# 20

# %%
# %load_ext autoreload
# %autoreload 2

# %%
input_client_name = 'penfed'
input_project_name = 'autoloan'
input_bureau_name = 'normalized'
model_type = 'standard_model_member_data' # options are 'standard_model', 'mega_model', 'standard_model_member_data', 'standard_model_ln_data', ''- None defaults to 'standard_model'

print(input_client_name, input_project_name, input_bureau_name, model_type)

# national_model_id = 'nationalmodel1b'
# Out:
# penfed autoloan normalized standard_model_member_data

# %% [markdown]
# ## Create a national model

# %%
# client' feature selection model

feature_selection_model_id = 'nationalmodel1a'

# %%
feature_selection_model_output_path = f'/d/shared/users/lyt/penfed_poc1_national_models/{feature_selection_model_id}'
feature_selection_model_output_path
# Out:
# '/d/shared/users/lyt/penfed_poc1_national_models/nationalmodel1a'

# %%
config = {
  "model_type": "standard_model",
  "storage_location": "s3",
  "lookalike": {
    "bureau": "transunion",
    "accounts":[
      "auto"
    ],
    "splits": [
      "train",
      "valid",
      "test"
    ],
    "pull_names": None,
    "states": None,
    "max_row": 1000,
    "tables": ['trade', 'inq', 'bnkr', 'collec', 'target', 'app', 'member'],
  },
  "model_config": {
      "data_split": {
          "train": {
            "start_date": "2016-04-01",
            "end_date": "2021-04-01"
          },
          "valid": {
            "start_date": "2021-04-01",
            "end_date": "2021-07-01"
          },
          "test": {
            "start_date": "2021-07-01",
            "end_date": "2022-01-01"
          }
    },
    "target": "final_DQ60_m24",
    "base_features": f'{feature_selection_model_output_path}/keep_features.json',
#    "feature_filter_rules": "/home/lyt/CODEBASE/model-engine_penfed/model-engine/model_engine/assets/power/feature_rules/intuitive_features.json",
    "memory_efficient": True,
    "pipeline_factory": None,
    "bivariate_fe_instructions": [],
    "monotonic_constraints_list": [],
    "exclusion_list": [],
    "feature_definition_list": [],
    "key_factor_mapping_list": [],
    "fold_valid": True,
    "mandatory_features": []
  }
}

# %%
national_model_id = 'nationalmodel1b_tu_test'
national_model_output_path = f'/d/shared/users/lyt/penfed_poc1_national_models/{national_model_id}'

# %%
national_model_output_path
# Out:
# '/d/shared/users/lyt/penfed_poc1_national_models/nationalmodel1b_tu_test'

# %%
nmb = NationalModelBuilder(
    configuration=config,
    model_output_path=national_model_output_path,
    overwrite_model_output=True
)
nmb.run()
# Out:
# Attempting to create a national model with full data split here /d/shared/users/lyt/penfed_poc1_national_models/nationalmodel1b_tu_test/supporting_model
# Sampling transunion, national_3_refresh
# Sampling transunion, national_4
# Sampling transunion, national_3_refresh
# Sampling transunion, national_4
# Sampling transunion, national_3_refresh
# Sampling transunion, national_4
# WARNING:py.warnings:Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 11.0.0, and the legacy implementation will be removed in a future version.
#
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# /home/lyt/.conda/envs/penfed_modeling/lib/python3.10/site-packages/fsspec/registry.py:290: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# ...
# -------------------------
# Name: app
# Transformer type: None
# Number of features: 18
# Time spent: 0.016s
# -------------------------
# Name: bnkr
# Transformer type: None
# Number of features: 8
# Time spent: 0.016s
# -------------------------
# Name: collec
# Transformer type: None
# Number of features: 5
# Time spent: 0.016s
# -------------------------
# Name: inq
# Transformer type: None
# Number of features: 13
# Time spent: 0.016s
# -------------------------
# Name: member
# Transformer type: None
# Number of features: 28
# Time spent: 0.022s
# -------------------------
# Name: trade
# Transformer type: None
# Number of features: 246
# Time spent: 0.034s
# -------------------------
# Name: app FE
# Transformer type: OneToOneEngine
# Number of features: 0
# Time spent: 0.047s
# -------------------------
# Name: bnkr FE
# Transformer type: ManyToOneEngine
# Number of features: 8
# Time spent: 0.048s
# -------------------------
# Name: collec FE
# Transformer type: ManyToOneEngine
# Number of features: 5
# Time spent: 0.050s
# -------------------------
# Name: inq FE
# Transformer type: InquiryFeatureEngine
# Number of features: 13
# Time spent: 0.049s
# -------------------------
# Name: member FE
# Transformer type: TradelineFeatureEngine
# Number of features: 28
# Time spent: 0.064s
# -------------------------
# Name: trade FE
# Transformer type: TradelineFeatureEngine
# Number of features: 246
# Time spent: 0.106s
# -------------------------
# Name: Merge data
# Transformer type: Concat
# Number of features: 300
# Time spent: 0.253s
# WARNING:py.warnings:No blacklisted columns were found in dataframe.
#
# WARNING:py.warnings:`dropped_features_` is empty. Input dataframe is returned.
# -------------------------
# Name: FillNA
# Transformer type: FillNA
# Number of features: 300
# Time spent: 4.712s
# -------------------------
# Name: GeneralFeatureSelection
# Transformer type: GeneralFeatureSelection
# Number of features: 300
# Time spent: 0.003s
# [0]	train-auc:0.50000	val-auc:nan
# [100]	train-auc:0.50000	val-auc:nan
# [200]	train-auc:0.50000	val-auc:nan
# INFO:zaml.artifact_engine.logger:Finished <pipeline_fitter>, total time spent: 0:00:06.136616
# INFO:zaml.artifact_engine.logger:Executing FittedPipeline <pipeline>...
# INFO:zaml.artifact_engine.logger:Finished <pipeline>, total time spent: 0:00:00.000438
# INFO:zaml.artifact_engine.logger:Executing FitTimeInfoArtifact <fit_time_info>...
# INFO:zaml.artifact_engine.logger:Finished <fit_time_info>, total time spent: 0:00:00.000288
# INFO:zaml.artifact_engine.logger:Executing PipeFactoryArtifact <pipe_factory>...
# INFO:zaml.artifact_engine.logger:Finished <pipe_factory>, total time spent: 0:00:00.000349
# INFO:zaml.artifact_engine.logger:Executing FittedModel <model>...
# INFO:zaml.artifact_engine.logger:Finished <model>, total time spent: 0:00:00.000321
# INFO:zaml.artifact_engine.logger:Executing FeDataArtifact <train_fe_data>...
# -------------------------
# Name: app
# Transformer type: None
# Number of features: 18
# Time spent: 0.000s
# -------------------------
# Name: bnkr
# Transformer type: None
# Number of features: 8
# Time spent: 0.000s
# -------------------------
# Name: collec
# Transformer type: None
# Number of features: 5
# Time spent: 0.000s
# -------------------------
# Name: inq
# Transformer type: None
# Number of features: 13
# Time spent: 0.000s
# -------------------------
# Name: member
# Transformer type: None
# Number of features: 28
# Time spent: 0.000s
# -------------------------
# Name: trade
# Transformer type: None
# Number of features: 246
# Time spent: 0.000s
# -------------------------
# Name: app FE
# Transformer type: OneToOneEngine
# Number of features: 0
# Time spent: 0.017s
# -------------------------
# Name: bnkr FE
# Transformer type: ManyToOneEngine
# Number of features: 8
# Time spent: 0.017s
# -------------------------
# Name: collec FE
# Transformer type: ManyToOneEngine
# Number of features: 5
# Time spent: 0.017s
# -------------------------
# Name: inq FE
# Transformer type: InquiryFeatureEngine
# Number of features: 13
# Time spent: 0.017s
# -------------------------
# Name: member FE
# Transformer type: TradelineFeatureEngine
# Number of features: 28
# Time spent: 0.022s
# -------------------------
# Name: trade FE
# Transformer type: TradelineFeatureEngine
# Number of features: 246
# Time spent: 0.038s
# -------------------------
# Name: Merge data
# Transformer type: Concat
# Number of features: 300
# Time spent: 0.125s
# WARNING:py.warnings:`dropped_features_` is empty. Input dataframe is returned.
#
# INFO:zaml.artifact_engine.logger:Finished <train_fe_data>, total time spent: 0:00:02.511529
# INFO:zaml.artifact_engine.logger:Executing FeDataArtifact <valid_fe_data>...
# -------------------------
# Name: FillNA
# Transformer type: FillNA
# Number of features: 300
# Time spent: 2.257s
# -------------------------
# Name: GeneralFeatureSelection
# Transformer type: GeneralFeatureSelection
# Number of features: 300
# Time spent: 0.001s
# -------------------------
# Name: app
# Transformer type: None
# Number of features: 18
# Time spent: 0.000s
# -------------------------
# Name: bnkr
# Transformer type: None
# Number of features: 8
# Time spent: 0.000s
# -------------------------
# Name: collec
# Transformer type: None
# Number of features: 5
# Time spent: 0.000s
# -------------------------
# Name: inq
# Transformer type: None
# Number of features: 13
# Time spent: 0.000s
# -------------------------
# Name: member
# Transformer type: None
# Number of features: 28
# Time spent: 0.000s
# -------------------------
# Name: trade
# Transformer type: None
# Number of features: 246
# Time spent: 0.000s
# -------------------------
# Name: app FE
# Transformer type: OneToOneEngine
# Number of features: 0
# Time spent: 0.016s
# -------------------------
# Name: bnkr FE
# Transformer type: ManyToOneEngine
# Number of features: 8
# Time spent: 0.017s
# -------------------------
# Name: collec FE
# Transformer type: ManyToOneEngine
# Number of features: 5
# Time spent: 0.016s
# -------------------------
# Name: inq FE
# Transformer type: InquiryFeatureEngine
# Number of features: 13
# Time spent: 0.017s
# -------------------------
# Name: member FE
# Transformer type: TradelineFeatureEngine
# Number of features: 28
# Time spent: 0.021s
# -------------------------
# Name: trade FE
# Transformer type: TradelineFeatureEngine
# Number of features: 246
# Time spent: 0.036s
# -------------------------
# Name: Merge data
# Transformer type: Concat
# Number of features: 300
# Time spent: 0.114s
# WARNING:py.warnings:`dropped_features_` is empty. Input dataframe is returned.
#
# INFO:zaml.artifact_engine.logger:Finished <valid_fe_data>, total time spent: 0:00:02.934779
# INFO:zaml.artifact_engine.logger:Executing FeDataArtifact <test_fe_data>...
# -------------------------
# Name: FillNA
# Transformer type: FillNA
# Number of features: 300
# Time spent: 2.696s
# -------------------------
# Name: GeneralFeatureSelection
# Transformer type: GeneralFeatureSelection
# Number of features: 300
# Time spent: 0.001s
# -------------------------
# Name: app
# Transformer type: None
# Number of features: 18
# Time spent: 0.000s
# -------------------------
# Name: bnkr
# Transformer type: None
# Number of features: 8
# Time spent: 0.000s
# -------------------------
# Name: collec
# Transformer type: None
# Number of features: 5
# Time spent: 0.000s
# -------------------------
# Name: inq
# Transformer type: None
# Number of features: 13
# Time spent: 0.000s
# -------------------------
# Name: member
# Transformer type: None
# Number of features: 28
# Time spent: 0.000s
# -------------------------
# Name: trade
# Transformer type: None
# Number of features: 246
# Time spent: 0.000s
# -------------------------
# Name: app FE
# Transformer type: OneToOneEngine
# Number of features: 0
# Time spent: 0.017s
# -------------------------
# Name: bnkr FE
# Transformer type: ManyToOneEngine
# Number of features: 8
# Time spent: 0.017s
# -------------------------
# Name: collec FE
# Transformer type: ManyToOneEngine
# Number of features: 5
# Time spent: 0.018s
# -------------------------
# Name: inq FE
# Transformer type: InquiryFeatureEngine
# Number of features: 13
# Time spent: 0.018s
# -------------------------
# Name: member FE
# Transformer type: TradelineFeatureEngine
# Number of features: 28
# Time spent: 0.023s
# -------------------------
# Name: trade FE
# Transformer type: TradelineFeatureEngine
# Number of features: 246
# Time spent: 0.041s
# -------------------------
# Name: Merge data
# Transformer type: Concat
# Number of features: 300
# Time spent: 0.131s
# WARNING:py.warnings:`dropped_features_` is empty. Input dataframe is returned.
#
# INFO:zaml.artifact_engine.logger:Finished <test_fe_data>, total time spent: 0:00:02.713998
# INFO:zaml.artifact_engine.logger:Executing StaticAssetArtifact <static_asset>...
# -------------------------
# Name: FillNA
# Transformer type: FillNA
# Number of features: 300
# Time spent: 2.447s
# -------------------------
# Name: GeneralFeatureSelection
# Transformer type: GeneralFeatureSelection
# Number of features: 300
# Time spent: 0.001s
# INFO:zaml.artifact_engine.logger:Finished <static_asset>, total time spent: 0:00:01.372103
# INFO:zaml.artifact_engine.logger:Executing TrainHistoryArtifact <train_history>...
# INFO:zaml.artifact_engine.logger:Finished <train_history>, total time spent: 0:00:00.000736
# INFO:zaml.artifact_engine.logger:Executing BestModelParamsArtifact <best_model_params>...
# INFO:zaml.artifact_engine.logger:Finished <best_model_params>, total time spent: 0:00:00.000642
# INFO:zaml.artifact_engine.logger:Executing ScoresArtifact <train_scores>...
# INFO:zaml.artifact_engine.logger:Finished <train_scores>, total time spent: 0:00:00.048785
# INFO:zaml.artifact_engine.logger:Executing SubmodelScoresArtifact <train_submodel_scores>...
# INFO:zaml.artifact_engine.logger:Finished <train_submodel_scores>, total time spent: 0:00:00.001886
# INFO:zaml.artifact_engine.logger:Executing ScoresArtifact <valid_scores>...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/.conda/envs/penfed_modeling/lib/python3.10/site-packages/zaml/artifact_engine/artifact_manager.py:360, in ArtifactManager._generate_single_node(self, node, optional_artifacts_set)
#     359 try:
# --> 360     generated_output = node.generate(**node_inputs)
#     361 except Exception as e:
#
# File ~/.conda/envs/penfed_modeling/lib/python3.10/site-packages/zaml/artifact_engine/artifacts/base.py:72, in TaggedBaseArtifact.generate(self, **inputs)
#      71 renamed_inputs = rename_inputs(self.tag, inputs)
# ---> 72 return self.tagged_generate(**renamed_inputs)
#
# File ~/.conda/envs/penfed_modeling/lib/python3.10/site-packages/zaml/artifact_engine/artifacts/scores.py:39, in ScoresArtifact.tagged_generate(self, model, fe_data)
#      23 """
#      24 Generate scores from given featured engineered data and using given model.
#      25
#    (...)
#      37     Score predictions from given model.
#      38 """
# ---> 39 scores = model.predict(fe_data)
#      40 scores.name = 'final_model_predictions'
#
# File ~/.conda/envs/penfed_modeling/lib/python3.10/site-packages/zaml/model/modeling/models/tree_models.py:524, in XGBoostModel.predict(self, data, output_margin, ntree_limit)
#     523 predictions = self.model.predict(xgb.DMatrix(data), output_margin=output_margin, iteration_range=iteration_range)
# --> 524 pred_series = pd.Series(predictions)
#     525 if isinstance(data, pd.DataFrame):
#
# File ~/.conda/envs/penfed_modeling/lib/python3.10/site-packages/pandas/core/series.py:509, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     508 else:
# --> 509     data = sanitize_array(data, index, dtype, copy)
#     511     manager = get_option("mode.data_manager")
#
# File ~/.conda/envs/penfed_modeling/lib/python3.10/site-packages/pandas/core/construction.py:607, in sanitize_array(data, index, dtype, copy, allow_2d)
#     605             subarr = maybe_infer_to_datetimelike(subarr)
# --> 607 subarr = _sanitize_ndim(subarr, data, dtype, index, allow_2d=allow_2d)
#     609 if isinstance(subarr, np.ndarray):
#     610     # at this point we should have dtype be None or subarr.dtype == dtype
#
# File ~/.conda/envs/penfed_modeling/lib/python3.10/site-packages/pandas/core/construction.py:666, in _sanitize_ndim(result, data, dtype, index, allow_2d)
#     665         return result
# --> 666     raise ValueError(
#     667         f"Data must be 1-dimensional, got ndarray of shape {data.shape} instead"
#     668     )
#     669 if is_object_dtype(dtype) and isinstance(dtype, ExtensionDtype):
#     670     # i.e. PandasDtype("O")
#
# ValueError: Data must be 1-dimensional, got ndarray of shape (0, 0) instead
#
# During handling of the above exception, another exception occurred:
#
# ArtifactGenerateError                     Traceback (most recent call last)
# Cell In[14], line 6
#       1 nmb = NationalModelBuilder(
#       2     configuration=config,
#       3     model_output_path=national_model_output_path,
#       4     overwrite_model_output=True
#       5 )
# ----> 6 nmb.run()
#
# File ~/CODEBASE/model-engine_penfed/model-engine/model_engine/power/post_sale/national_model_builder.py:604, in NationalModelBuilder.run(self)
#     602 self.inject_model_config()
#     603 super().archive_config(self.config, 'injected_model_config.json', self.artifacts_path)  # to track what's happening at archive_input_config
# --> 604 self.build_national_model()
#
# File ~/CODEBASE/model-engine_penfed/model-engine/model_engine/power/post_sale/national_model_builder.py:315, in NationalModelBuilder.build_national_model(self)
#     313 supporting_model_path = os.path.join(self.artifacts_path, 'supporting_model')
#     314 print(f'Attempting to create a national model with full data split here {supporting_model_path}')
# --> 315 self._build_full_split_model(self.config['model_config'], supporting_model_path, self.manifest)
#     316 # 2nd model by folding the validation into training set
#     317 print(f'Attempting to create a national model by folding validation into training here {self.artifacts_path}')
#
# File ~/CODEBASE/model-engine_penfed/model-engine/model_engine/power/post_sale/national_model_builder.py:516, in NationalModelBuilder._build_full_split_model(self, model_config, model_path, manifest)
#     514     data_section = self._inject_megamodel_configuraton_asset(data_section, self.config['model_config']['megamodel_config_options'])
#     515 mb_asset = super().make_mb_asset(data_section, model_config)
# --> 516 build_model(mb_asset, model_path, manifest=manifest)
#     517 self._add_data_description(model_path, model_path, 'data_description.json')
#
# File ~/CODEBASE/model-engine_penfed/model-engine/model_engine/model_builder/build_model.py:53, in build_model(asset, output_location, manifest)
#      50 builder.configure_run(return_outputs=True)
#      52 print('building model')
# ---> 53 artifact_output = builder.generate(input_data=data, input_asset=state['input_asset'], **config)
#      55 # Output the results to different system
#      56 if output_system == 'dshared':
#
# File ~/CODEBASE/model-engine_penfed/model-engine/model_engine/model_builder/model_builder.py:136, in ModelBuilder.generate(self, **inputs)
#     134 def generate(self, **inputs):
#     135     start_time = time.time()
# --> 136     artifact_output = super().generate(**inputs)
#     137     time_spent = time.time() - start_time
#     138     run_time = { 'run_time': '{:.3f}s'.format(time_spent)}
#
# File ~/.conda/envs/penfed_modeling/lib/python3.10/site-packages/zaml/artifact_engine/artifact_manager.py:315, in ArtifactManager.generate(self, **inputs)
#     313 start_time = time()
#     314 logger.info(f'Executing {type(node).__name__} <{node.name}>...')
# --> 315 artf = self._generate_single_node(node, optional_artifacts_set)
#     316 if not isinstance(artf, _NoOutput):
#     317     self.artifacts_pool[node.name] = artf
#
# File ~/.conda/envs/penfed_modeling/lib/python3.10/site-packages/zaml/artifact_engine/artifact_manager.py:368, in ArtifactManager._generate_single_node(self, node, optional_artifacts_set)
#     366         generated_output = artf_e  # put an Exception in the pool for downstream artifacts to recognize the error.
#     367     else:
# --> 368         raise artf_e
#     369 return generated_output
#
# ArtifactGenerateError: Artifact <valid_scores> of type <ScoresArtifact> is not generated successfully and raises an error: ValueError: Data must be 1-dimensional, got ndarray of shape (0, 0) instead

# %%
temp_equifax = pd.read_parquet('s3://power-equifax-prod/NATIONAL/PROCESSED/DATA/BUREAU=equifax/FORMAT=cms_6/TABLE=trade_fe/PULL_NAME=national_2/FEW_VERSION=0.1.0/ME_VERSION=v1.10.2/DATE_OF_REQUEST=2020-06-30/ACCOUNT_TYPE_CODE=3A/GEO_STATE_CODE=LA/a26b42f3562749e2baad25b01cbb459e-0.parquet')
temp_equifax.shape
# Out:
# (414, 8464)

# %%
temp_tu4r = pd.read_parquet('s3://power-transunion-prod/NATIONAL/PROCESSED/DATA/BUREAU=transunion/FORMAT=TU4R/TABLE=trade_fe/PULL_NAME=national_4/FEW_VERSION=0.1.0/ME_VERSION=v1.10.2/DATE_OF_REQUEST=2020-06-30/ACCOUNT_TYPE_CODE=AU/GEO_STATE_CODE=VT/9d535aab53a34c699d44575d4e076983-0.parquet')
temp_tu4r.shape
# Out:
# (11415, 8464)

# %%
'trade_hcAmt_accts_never_dq__max_by_acctType_utility' in temp_equifax.columns
# Out:
# True

# %%
'trade_hcAmt_accts_never_dq__max_by_acctType_utility' in temp_tu4r.columns
# Out:
# True

# %%
scoreFiles = []

for j in ['_auc.json','_ks.json']:
    for i in ['train', 'test']:
        scoreFiles.append(i+j)
        
scoreFiles_model = {}
for i in scoreFiles:
    name = i.split('.')[0]
    # print(name)
    scoreFiles_model[name] = json.load(open(os.path.join(national_model_output_path, i), 'rb'))


for i in scoreFiles_model:
    print(i, scoreFiles_model[i])

# %%
scoreFiles = []

for j in ['_auc.json','_ks.json']:
    for i in ['train', 'test']:
        scoreFiles.append(i+j)
        
scoreFiles_model = {}
for i in scoreFiles:
    name = i.split('.')[0]
    # print(name)
    scoreFiles_model[name] = json.load(open(os.path.join(feature_selection_model_output_path, i), 'rb'))


for i in scoreFiles_model:
    print(i, scoreFiles_model[i])
# Out:
# train_auc {'auc': 0.8686551218870335}
# test_auc {'auc': 0.8535502746706296}
# train_ks {'ks': 0.5812319389933264}
# test_ks {'ks': 0.5624095655404407}

# %%
ftr_importance = pd.read_parquet('/d/shared/users/lyt/penfed_poc1_national_models/nationalmodel1a/feature_importance.parquet')
ftr_importance.head(10)
# Out:
#                                              feature  importance
# 0  trade_clAmt_accts_with_rcntPmt__mean_by_prtfTy...    0.003050
# 1  trade_clAmt_accts_never_dq__sum_by_prtfType_re...    0.003048
# 2      inq_inquiries__count_by_indCode_auto_mortgage    0.003005
# 3                    inq_inquiries_in_last_year__sum    0.002900
# 4  trade_clAmt_active_accts__mean_by_prtfType_rev...    0.002854
# 5                                 inq_inquiries__sum    0.002753
# 6           trade_hcAmt__min_by_prtfType_installment    0.002750
# 7               trade_blncAmt__mean_by_acctType_auto    0.002422
# 8                    trade_hcAmt_accts_never_dq__sum    0.002365
# 9               trade_hcAmt_all_non_derog_accts__sum    0.002268

# %%
ftr_importance[ftr_importance.feature == 'trade_hcAmt_accts_never_dq__max_by_acctType_utility']
# Out:
#                                                feature  importance
# 277  trade_hcAmt_accts_never_dq__max_by_acctType_ut...    0.000139
